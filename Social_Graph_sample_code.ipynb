# %%
import requests
from bs4 import BeautifulSoup
from datetime import datetime
import pandas as pd
import numpy as np
import urllib.parse as urlparse
import re
import spacy
nlp = spacy.load('en')

# %% [markdown]
# ### Extracting event information from one page.
#
# This is part of my code for a project that involved gathering/scraping data from a website.
#
# You can read about the whole project here: https://showmikpodder.github.io/Peapod/socialite-connections.html
#
# I suggest you read along with that link as you go through the code to get an idea of what is trying to being accomplished.
#
# This is just the extraction bit of the project.

# %%
# url of webpage that contains all links to events. 
url = 'http://www.newyorksocialdiary.com/party-pictures'

# %%
# there are multiple pages of events, 
# to just extract from just the first page, 
# make a page variable for use in requests method, 
# set to 0 for first page extraction (response request object)
page = 0 

# store the raw html code in events_on_page variable, 
# use bs4 prettify to make legible. 

events_on_page = requests.get(url, params={"page":""})
soup = BeautifulSoup(events_on_page.text, "lxml")

pretty_soup = soup.prettify()

# to give an idea of what the middle of the html looks like
print(pretty_soup[10000:15000])
# Out:
# iv class="email-subscribe">
#        <form action="http://members.newyorksocialdiary.com/subscribe/subscribe.tml" method="POST">
#         <input class="email" name="email" onblur="if(this.value == '') { this.value = 'Enter your email'; }" onfocus="if(this.value == 'Enter your email') { this.value = ''; }" type="text" value="Enter your email"/>
#         <input class="subscribe" name="subscribe" type="submit" value="GO"/>
#         <input name="list" type="hidden" value="nysdsubscribers"/>
#         <input name="confirm" type="hidden" value="none"/>
#         <input name="showconfirm" type="hidden" value="F"/>
#         <input name="url" type="hidden" value="http://www.newyorksocialdiary.com"/>
#         <input name="appendsubinfotourl" type="hidden" value="T"/>
#        </form>
#       </div>
#      </div>
#      <div class="panel-pane pane-ad pane-12 adverserve-ad advertserve-12">
#       <!-- BEGIN ADVERTPRO CODE BLOCK -->
#       <script type="text/javascript">
#        document.write('<scr' + 'ipt src="http://newyorksocialdiary.advertserve.com/servlet/view/banner/javascript/zone?zid=12&pid=0&random=' + Math.floor(89999999 * Math.random() + 10000000) + '&millis=' + new Date().getTime() + '&referrer=' + encodeURIComponent(document.location) + '" type="text/javascript"></scr' + 'ipt>');
#       </script>
#       <!-- END ADVERTPRO CODE BLOCK -->
#      </div>
#     </div>
#    </div>
#    <header class="l-header" role="banner">
#     <div class="l-constrained">
#      <div class="l-branding site-branding">
#       <div class="l-region l-region--branding">
#        <div class="panel-pane pane-page-logo">
#         <a href="/" id="logo" rel="home" title="Home">
#          <img alt="Home" src="http://www.newyorksocialdiary.com/sites/all/themes/omega_nysd/nysd_weblogo_final.gif"/>
#         </a>
#        </div>
#       </div>
#      </div>
#     </div>
#    </header>
#    <div class="l-main l-constrained">
#     <div class="l-region l-region--navigation">
#      <div class="panel-pane pane-block pane-nice-menus-1">
#       <ul class="nice-menu nice-menu-down nice-menu-main-menu" id="nice-menu-1">
#        <li class="menu-1227 menu-path-node-134656 first odd ">
#         <a href="/nysd/socialdiarysectional">
#          Social Diary
#         </a>
#        </li>
#        <li class="menu-1215 menu-path-node-1912772 even ">
#         <a href="/nysd/partypictures">
#          Party Pictures
#         </a>
#        </li>
#        <li class="menu-1104 menuparent menu-path-front odd ">
#         <a href="/" title="">
#          Diary Features
#         </a>
#         <ul>
#          <li class="menu-1216 menu-path-node-1912773 first odd ">
#           <a href="/nysd/guestdiary">
#            Guest Diaries
#           </a>
#          </li>
#          <li class="menu-1234 menu-path-node-1912778 even ">
#           <a href="/nysd/nysdhouse">
#            House
#           </a>
#          </li>
#          <li class="menu-1219 menu-path-node-1912777 odd ">
#           <a href="/nysd/across">
#            Across the Nation
#           </a>
#          </li>
#          <li class="menu-1218 menu-path-node-1912774 even ">
#           <a href="/nysd/socialhistory">
#            Social History
#           </a>
#          </li>
#          <li class="menu-1223 menu-path-node-1912775 odd ">
#           <a href="/nysd/dining">
#            Dining
#           </a>
#          </li>
#          <li class="menu-1235 menu-path-node-1912779 even ">
#           <a href="/nysd/travel">
#            Travel
#           </a>
#          </li>
#          <li class="menu-1220 menu-path-node-1912776 odd ">
#           <a href="/nysd/artset">
#            Art Set
#           </a>
#          </li>
#          <li class="menu-1063 menu-path-taxonomy-term-57 even last">
#           <a href="/nysd/thelist">
#            The List / Cameo
#           </a>
#          </li>
#         </ul>
#        </li>
#        <li class="menu-1061 menu-path-calendar even ">
#         <a href="/calendar" title="">
#          Calendar
#         </a>
#        </li>
#        <li class="menu-1217 menu-path-node-283 odd ">
#         <a href="/nysd/archives">
#          Archives
#         </a>
#        </li>
#        <li class="menu-1359 menuparent menu-path-front even last">
#         <a href="/">
#          NYSD Beauty
#         </a>
#         <ul>
#          <li class="menu-1360 menu-path-node-1913645 first odd ">
#           <a href="/beauty-wellness/2015/beauty-and-wellness" title="Find out about beauty and wellness in NYC.">
#            Beauty &amp; Wellness
#           </a>
#          </li>
#          <li class="menu-1361 menu-path-nysd-beauty even last">
#           <a href="/nysd-beauty" target="_blank" title="See the selection of wonderful beauty products.">
#            Beauty Shop
#           </a>
#          </li>
#         </ul>
#        </li>
#       </ul>
#      </div>
#      <div class="panel-pane pane-block pane-search-api-page-default">
#       <form accept-charset="UTF-8" action="/party-pictures?page=" class="search-api-page-search-form-default" id="search-api-page-search-form-default" method="post">
#        <div>
#         <div class="form-item form-type-textfield form-item-keys-1">
#          <label class="e

# %%
# party event information live in <div class=”view-rows”> tags
# bs4 find_all finds all and stores in links variable.
links = soup.find_all('div', attrs={'class':'views-row'})

print("Total events in the first page: ", len(links))

links[:1]  #what the first couple elements of links looks like
# Out:
# Total events in the first page:  50
# [<div class="views-row views-row-1 views-row-odd views-row-first">
#  <span class="views-field views-field-title"> <span class="field-content"><a href="/party-pictures/2017/light-years-ahead">Light-years Ahead</a></span> </span>
#  <span class="views-field views-field-created"> <span class="field-content">Tuesday, November 28, 2017</span> </span> </div>]

# %%
# function for extracting 
# name of the event, link text and date of the event
# built to go through a specified list element in the links list above

def get_link_date(el):

    el_title = links[el].select('a')[0]
    url = el_title['href']
    date = links[el].select('span')[3]
    
    return el_title.text, url, datetime.strptime(str(date.text), '%A, %B %d, %Y')

# %%
# passing the first element of links list to get_link_date function.
# returns the party event name, link, 
# and a datetime object of when the event occured

get_link_date(0)
# Out:
# ('Light-years Ahead',
#  '/party-pictures/2017/light-years-ahead',
#  datetime.datetime(2017, 11, 28, 0, 0))

# %% [markdown]
# ### Building a Function that extracts from all the pages on the event list

# %%
# event_info variable will hold events information
event_info = []

def get_links(page):

    params = {"page":page}
    response = requests.get('http://www.newyorksocialdiary.com/party-pictures', params= params)
    soup = BeautifulSoup(response.text, "lxml")
    links = soup.find_all('div', attrs={'class':'views-row'})
    
    for i in range(len(links)):
        title = links[i].select('a')[0]
        url = title['href']
        date = links[i].select('span')[3]
        y = datetime.strptime(str(date.text), '%A, %B %d, %Y')
        x = (title.text, url, y) 
        event_info.append(x)
    return event_info

# %%
# recreated empty event_info variable
event_info = []

# noticed that there were 30 pages of events on the event pages list.
# so will need to go from page 0 to 30 in response requests object

for i in range(30):
    get_links(i)

# %%
print("Number of events collected: ",len(event_info))

# first couple events and their info tuples.
print(event_info[:5])
# Out:
# Number of events collected:  1495
# [('Light-years Ahead', '/party-pictures/2017/light-years-ahead', datetime.datetime(2017, 11, 28, 0, 0)), ('The Spirit of Collaboration', '/party-pictures/2017/the-spirit-of-collaboration', datetime.datetime(2017, 11, 22, 0, 0)), ('Blerancourt awards', '/party-pictures/2017/blerancourt-awards', datetime.datetime(2017, 11, 21, 0, 0)), ('Something Personal', '/party-pictures/2017/something-personal', datetime.datetime(2017, 11, 20, 0, 0)), ('Game changers', '/party-pictures/2017/game-changers', datetime.datetime(2017, 11, 17, 0, 0))]

# %%
# creating a cutoff point (date filter)
# only want parties from before 12/1/14

filtered_event_info = [x for x in event_info if x[2] <= datetime(2014, 12, 1, 0, 0)]

# %%
print("Number of events after the date filter: ",len(filtered_event_info))
# Out:
# Number of events after the date filter:  1193

# %% [markdown]
# ### Understanding which months had the most events

# %%
# creating a pandas dataframe out of the list of tuples (filtered_event_info).
df1 = pd.DataFrame(filtered_event_info, columns=['event','url', 'date'])

# adjusting the dates to be "Month-Year"
df1['date'] = df1['date'].dt.strftime('%b-%Y')

# counting the number of occurrences of each "Month-Year" combination
# essentially a count of all the events in each month.
df2 = df1['date'].value_counts()
# Out:
# datetime64[ns]

# %%
# what the first elements of df1 looks like.
df1.head()
# Out:
#                                                event  \
# 0  The Thanksgiving Day Parade from the ground up...
# 1                                        Gala Guests
# 2                                      Equal Justice
# 3                          Celebrating the Treasures
# 4                             Associates and Friends
#
#                                                  url      date
# 0  /party-pictures/2014/the-thanksgiving-day-para...  Dec-2014
# 1                   /party-pictures/2014/gala-guests  Nov-2014
# 2                 /party-pictures/2014/equal-justice  Nov-2014
# 3     /party-pictures/2014/celebrating-the-treasures  Nov-2014
# 4        /party-pictures/2014/associates-and-friends  Nov-2014

# %%
# what the first elements of df2 looks like.
df2.head()
# Out:
# May-2007    20
# Jun-2010    19
# Oct-2008    19
# Jul-2010    18
# Jul-2009    18
# Name: date, dtype: int64

# %%
# conversion of df2 into a list of tuples
popular_months = list(zip(list(df2.index),list(df2)))

# %%
# top 10 most popular months for events
popular_months[:10]
# Out:
# [('May-2007', 20),
#  ('Jun-2010', 19),
#  ('Oct-2008', 19),
#  ('Jul-2010', 18),
#  ('Jul-2009', 18),
#  ('Aug-2010', 18),
#  ('May-2010', 18),
#  ('Mar-2007', 18),
#  ('Mar-2010', 17),
#  ('May-2008', 17)]

# %% [markdown]
# ### Extracting captions from one event page

# %%
# testing code structure on a single event page before trying to extract from all the events

# test "Celebrating the neighborhood" event url

# using requests/bs4 to extract html code from web page.
url_html = requests.get('http://www.newyorksocialdiary.com/party-pictures/2015/celebrating-the-neighborhood')
soup1 = BeautifulSoup(url_html.text, "lxml")

# after inspection of html, noticed names of individuals in photos 
# are contained in <div class='photocaption'> tags for this particular page
captions = soup1.find_all('div', attrs={'class':'photocaption'})

# %%
# first couple captions on the page
captions[:3]
# Out:
# [<div align="center" class="photocaption">Glenn Adamson, Simon Doonan, Victoire de Castellane, Craig Leavitt, Jerome Chazen, Andi Potamkin, Ralph Pucci, Kirsten Bailey, Edwin Hathaway, and Dennis Freedman at the Museum of Art and Design's annual MAD BALL. </div>,
#  <div align="center" class="photocaption"> Randy Takian </div>,
#  <div align="center" class="photocaption"> Kamie Lightburn and Christopher Spitzmiller </div>]

# %% [markdown]
# ### Extracting all the captions from ALL the event pages

# %%
# isolating the urls from filtered_event_info list of tuples
# unzipping the tuples into component list of lists
x = list(zip(*filtered_event_info))

# list of urls is contained in second list, x[1]
event_urls = x[1]
print("Total number of event urls is ",len(event_urls))

print(event_urls[:3])
# Out:
# Total number of event urls is  1193
# ('/party-pictures/2014/the-thanksgiving-day-parade-from-the-ground-up', '/party-pictures/2014/gala-guests', '/party-pictures/2014/equal-justice')

# %%
# using urlparse to combine the partial urls above to a make a full url
full_path_test = urlparse.urljoin('http://www.newyorksocialdiary.com/', event_urls[0])

print(full_path_test)
# Out:
# http://www.newyorksocialdiary.com/party-pictures/2014/the-thanksgiving-day-parade-from-the-ground-up

# %%
# building a function that can iterate over all the event urls 
# and combines everything from above

# empty list that will hold raw captions that are extracted
raw_captions = []

def get_captions(path):
    full_path = urlparse.urljoin('http://www.newyorksocialdiary.com/', path)
    url_html = requests.get(full_path) #requests full html page of requested page
    url_html.text #returns the html text
    soup1 = BeautifulSoup(url_html.text, "lxml") #turns the html text into a soup object
    
    #after much trial and error found the captions in older event pages found in different html tags
    x = soup1.find_all('div', attrs={'class':'photocaption'})
    y = soup1.find_all('font', attrs={'face':'Verdana, Arial, Helvetica, sans-serif'})
    z = soup1.find_all('td', attrs={'class':'photocaption'})
    messy_captions = x + y + z
    
    for i in range(len(messy_captions)): #loops through captions list and returns the text
        raw_captions.append(messy_captions[i].text)#inputs the text into raw_captions list
    return raw_captions

# %%
# iterating over entire captions list and running get_captions function on each element.
# can take up to 10 minutes
raw_captions = []
for i in event_urls:
    get_captions(i)

# %%
print("The total number of captions captured: ",len(raw_captions))
# Out:
# The total number of captions captured:  131079

# %%
# there are some names and text in some of the captions
raw_captions[230:245]
# Out:
# [' Eleanor Noell ',
#  ' Melissa Errico ',
#  ' Outside the tent ',
#  ' Under the tent',
#  ' Jenny Price, Sharon Jacob, Stephanie Shuman, Gillian Miniter, and Deborah Roberts ',
#  ' Cynthia Conway, Tom Kempner, Luann Blowers, and David Blowers ',
#  ' Michael  and Jenny Price ',
#  ' Bob  and Suzanne Cochran ',
#  ' Patsy and Jeff Tarr ',
#  ' Fred and Stephanie Shuman ',
#  ' Gillian and Sylvester Miniter ',
#  ' Iffie Okoronkwo Aitkenhead, Agenia Clark, Deborah Roberts, and Fiona Rudin ',
#  ' Michael  and Lise Evans ',
#  ' Fe  and Alessandro Fendi ',
#  ' Jill Ross, Sharon Teles, and Eby McKay ']

# %%
# there are also lots of needless spaces
raw_captions[:5]
# Out:
# ['\n\n\n\n', '', '\n\n\n\n', '', '\n\n\n\n']

# %% [markdown]
# ### Cleaning the captions and extracting names out from them

# %% [markdown]
# Should have done so earlier but this is a good point to save what we have extracted in a pickle file

# %% [markdown]
# import ediblepickle
#
# dill.dump(raw_captions, open('nysd-captions.pkd', 'w'))
#
# raw_captions = dill.load(open('nysd-captions.pkd', 'r'))

# %%
# creating a dummy variable that i can work on
str_raw_captions = raw_captions

# %%
# some cleanup on the captions. removal of exess spaces and new lines and empty captions
for i in range(len(str_raw_captions)):
    str_raw_captions[i] = str_raw_captions[i].strip()
    str_raw_captions[i] = str_raw_captions[i].replace('\n', "") #replaces '\n' character
    str_raw_captions[i] = re.sub(r'\s+', ' ', str_raw_captions[i])

# %%
# removal of photographer captions
str_raw_captions = [caption for caption in str_raw_captions if not re.search(r'^Photographs by ',caption)]

# %%
# removal of empty elements
str_raw_captions = list(filter(None, str_raw_captions))

# %%
print('After some cleaning the list of captions now has ', len(str_raw_captions), 'elements')
# Out:
# After some cleaning the list of captions now has  108646 elements

# %% [markdown]
# This list of captions still contains honorifics such as Dr., Mr, Sir, etc

# %%
str_raw_captions[:10]
# Out:
# ['The scene at IDEAL School & Academy’s 10th Annual Gala.',
#  'Les Lieberman, Barri Lieberman, Isabel Kallman, Trish Iervolino, and Ron Iervolino',
#  'Chuck Grodin',
#  'Diana Rosario, Ali Sussman, Sarah Boll, Jen Zaleski, Alysse Brennan, and Lindsay Macbeth',
#  'Kelly and Tom Murro',
#  'Udo Spreitzenbarth',
#  'Ron Iervolino, Trish Iervolino, Russ Middleton, and Lisa Middleton',
#  'Barbara Loughlin, Dr. Gerald Loughlin, and Debbie Gelston',
#  'Julianne Michelle',
#  'Heather Robinson, Kiwan Nichols, Jimmy Nichols, Melanie Carbone, and Nancy Brown']

# %%
# honorifics cleaning, list of titles was created after making observations

# empty list where cleaned captions with no honorifics will be kept
nohonorifics_cleancaptions = []

def junk_title_cleaner(unclean_caption):
    h1=['Mr. ','Guest','U.S. Representative ',' M.D.', ' M.D.,','PhD','Ph.D.',' Jr.',' Sr.','Mrs. ','Miss ','Doctor ','Dr. ','Dr ','Chair ','CEO ','the Honorable ','Mayor ','Prince ','Baroness ', 'Princess ', 'Honorees ', 'Honoree',' MD']
    h3=['De', 'Highness ','Museum President ','Chief Curator ','Frick Director ','left ','right ','honoree ','de ','host ','dressed ','Police Commissioner ','Music Director ','Frick Trustee ','Historic Hudson Valley Trustee ', 'Museum President ','Public Theater Artistic Director ','Public Theater Executive Director ','Executive Director ','Cooper Union President ','The Hon. ','Dancing Chair ','Director Emerita ']
    h2=['Hon. ','Lord ','Senator ','Deputy ','Director ','Dean ','Actor ','Actress ',' Esq.', 'Gov ','Governor ','Father ','Congresswoman ','Congressman ', 'Countess ','Awardee ','Chairman ','Commissioner ','Lady ','Ambassador ','President ','CEO ', ' von', ' van']
    hwords=h1 + h2 + h3
    honorifics = '|'.join(list(set(hwords))) ###Mr. and Mrs. couples have been ignored. this maybe problematic later on.
    x = unclean_caption.replace(", and "," and ") #Replaces the ',/sand' with '/sand/s'
    x = re.sub(honorifics, '', x)  #Replaces honorifics with empty spaces
    #if x[-1] == ",":
    #    x = list(x)
    #    x[-1] =''
    #    x = ''.join(x)
        
    x = x.replace(", and "," and ")
    notitles_clean_captions = x #cleaned of all the junk titles and such
    nohonorifics_cleancaptions.append(notitles_clean_captions)
    return nohonorifics_cleancaptions

# %%
nohonorifics_cleancaptions = []

# iterates through every caption and runs through the cleaner
for i in str_raw_captions:
    junk_title_cleaner(i)

# %%
nohonorifics_cleancaptions[:10]
# Out:
# ['The scene at IDEAL School & Academy’s 10th Annual Gala.',
#  'Les Lieberman, Barri Lieberman, Isabel Kallman, Trish Iervolino and Ron Iervolino',
#  'Chuck Grodin',
#  'Diana Rosario, Ali Sussman, Sarah Boll, Jen Zaleski, Alysse Brennan and Lindsay Macbeth',
#  'Kelly and Tom Murro',
#  'Udo Spreitzenbarth',
#  'Ron Iervolino, Trish Iervolino, Russ Middleton and Lisa Middleton',
#  'Barbara Loughlin, Gerald Loughlin and bbie Gelston',
#  'Julianne Michelle',
#  'Heather Robinson, Kiwan Nichols, Jimmy Nichols, Melanie Carbone and Nancy Brown']

# %%
# fixing captions that have couples in them and have unnecessary "ands"
# ALSO identifies captions with married couples
captions_with_couples = []
captions_with_no_and = []

# regex identifies unnessary 'ands' ('....Melanie Carbone AND Nancy Brown')
notsame_family_and_removal_regex = r'[A-Za-z]+\s+[A-Za-z]+\s+and\s+[A-Za-z]+\s+[A-Za-z]'

def and_removal_noncouples(caption, notsame_family_and_removal_regex):
    if len(re.findall(notsame_family_and_removal_regex, caption.strip())) > 0:
        names = caption.split(' and ')
        if len(names) == 2:
            fixed_string = ', '.join([names[0], names[1]])
            captions_with_no_and.append(fixed_string)
    if len(re.findall(notsame_family_and_removal_regex, caption.strip())) == 0:
        names = caption
        captions_with_couples.append(names)
    return

# %%
captions_with_couples = []
captions_with_no_and = []

for i in nohonorifics_cleancaptions:
    and_removal_noncouples(i, notsame_family_and_removal_regex)

# %%
# regex identifies captions with couples in them
same_family_regex = r'^[A-Za-z]+\s+and\s+[A-Za-z]+\s+[A-Za-z]+'
testcleancaptions_nocouples =[]

# Takes a caption that contains a couple (Mike and Sophie Riddle) 
# turns to (Mike Riddle and Sophie Riddle)
def same_family_couples(caption, same_family_regex):
    fixed_caption = caption
    divided_by_commas = caption.split(',')
    for string in divided_by_commas:
        if len(re.findall(same_family_regex, string.strip())) >0:
            names = string.split(' and ')
            if len(names) == 2:
                first_name = names[0]
                second_full_name = names[1]
                common_last_name = second_full_name.split()[1]
                fixed_string = ' '.join([first_name, common_last_name, ',', second_full_name])
                fixed_caption = fixed_caption.replace(string, fixed_string)
                testcleancaptions_nocouples.append(fixed_caption)
    return testcleancaptions_nocouples

# %%
for i in captions_with_couples:
    same_family_couples(i, same_family_regex)

#combining the final list of captions 
testcleancaptions_nocouples
final_clean_list = captions_with_no_and +testcleancaptions_nocouples

# %%
final_clean_list[:20]
# Out:
# ['Les Lieberman, Barri Lieberman, Isabel Kallman, Trish Iervolino, Ron Iervolino',
#  'Diana Rosario, Ali Sussman, Sarah Boll, Jen Zaleski, Alysse Brennan, Lindsay Macbeth',
#  'Ron Iervolino, Trish Iervolino, Russ Middleton, Lisa Middleton',
#  'Barbara Loughlin, Gerald Loughlin, bbie Gelston',
#  'Heather Robinson, Kiwan Nichols, Jimmy Nichols, Melanie Carbone, Nancy Brown',
#  'Bill Mack, Les Lieberman',
#  'David Lyden, Patricia Sorenson',
#  'Jimmy Cayne, Vince Tese, Pat Cayne',
#  'Stuart Oran, Les Lieberman, Hilary Oran',
#  'Vince Tese, Chuck Grodin',
#  'Dwight Gooden, Les Lieberman',
#  'Amy Cunningham-Bussel, Ray Mirra, Tyler Janovitz',
#  'Dan Shedrick, Samara Heafitz',
#  'Bart Scott, Mark Laplander',
#  'Mitch Rubin, Audra Zuckerman, Michelle Smith, Kenneth Mehlman, Julia Harquail, John Hackett',
#  'Audra Zuckerman, Michelle Smith, Julia Harquail',
#  'Judy Poller, Rob Affuso',
#  'David Byrnes, Concetta Bencivenga',
#  'Henry Kravis, Kenneth Mehlman, Mitch Rubin',
#  'Anne Jameson, Jay Eisenhofer']

# %%
print('The final length of my list of captions is ',len(final_clean_list))
# Out:
# The final length of my list of captions is  83915

# %% [markdown]
# dill.dump(final_clean_list, open('final_clean_presort.pkd', 'w'))

# %% [markdown]
# ### Name extraction from the captions using NLP

# %%
only_names_captions = []
####EXTRACTS only the names from each caption.

# good reference for spacy usage: 
# http://textminingonline.com/getting-started-with-spacy


def spacy_name_extraction(final_clean_list):
    #iterates through each caption
    for i in final_clean_list:
        #tokenize each caption
        doc1 = nlp(i)
        
        #empty temp list where identified names will be inserted
        names = []
        
        #iterates through each token in a caption and identifies the which tokens are names
        for ent in doc1.ents:
            # 378 is token label for names
            if ent.label == 378:
                x = ent.text.strip()
                names.append(x)
        
        #gathers final names into an overall list of names        
        only_names_captions.append(names)
                
    return only_names_captions

# %%
only_names_captions = []

# iterates through entire captions list and returns a list of names in each caption
# can take up to 10 minutes to iterate over all 80k captions.

spacy_name_extraction(final_clean_list)
# Out:
# [['Les Lieberman',
#   'Barri Lieberman',
#   'Isabel Kallman',
#   'Trish Iervolino',
#   'Ron Iervolino'],
#  ['Diana Rosario',
#   'Ali Sussman',
#   'Sarah Boll',
#   'Jen Zaleski',
#   'Alysse Brennan',
#   'Lindsay Macbeth'],
#  ['Ron Iervolino', 'Trish Iervolino', 'Russ Middleton', 'Lisa Middleton'],
#  ['Barbara Loughlin', 'Gerald Loughlin', 'Gelston'],
#  ['Heather Robinson',
#   'Kiwan Nichols',
#   'Jimmy Nichols',
#   'Melanie Carbone',
#   'Nancy Brown'],
#  ['Bill Mack', 'Les Lieberman'],
#  ['David Lyden', 'Patricia Sorenson'],
#  ['Jimmy Cayne', 'Vince Tese', 'Pat Cayne'],
#  ['Stuart Oran', 'Les Lieberman', 'Hilary Oran'],
#  ['Vince Tese', 'Chuck Grodin'],
#  ['Dwight Gooden', 'Les Lieberman'],
#  ['Amy Cunningham-Bussel', 'Ray Mirra', 'Tyler Janovitz'],
#  ['Dan Shedrick', 'Samara Heafitz'],
#  ['Bart Scott', 'Mark Laplander'],
#  ['Mitch Rubin',
#   'Audra Zuckerman',
#   'Michelle Smith',
#   'Kenneth Mehlman',
#   'John Hackett'],
#  ['Audra Zuckerman', 'Michelle Smith', 'Julia Harquail'],
#  ['Judy Poller', 'Rob Affuso'],
#  ['David Byrnes', 'Concetta Bencivenga'],
#  ['Henry Kravis', 'Kenneth Mehlman', 'Mitch Rubin'],
#  ['Anne Jameson', 'Jay Eisenhofer'],
#  ['Billy Morrissey', 'Brown'],
#  ['Carter Bays', 'Craig Thomas'],
#  ['Melissa Errico', 'Todd Hollander'],
#  ['George Lichtblau', 'Anne Lichtblau', 'Sig Ackerman'],
#  ['Daniel Murphy', 'Murphy', 'Jessica Farrell', 'Ken Farrell'],
#  ['Jena Silverman', 'John Silverman', 'Tess Silverman', 'Dara Silverman'],
#  ['Jaime Gleicher', 'Jared Seligman'],
#  ['Fred Feiner', 'Sandie Greene', 'Bob Greene'],
#  ['Kelly Mulderry', 'Ted Murphy', 'Marci Murphy'],
#  ['Michael Cominotto', 'Gigi Grimstad', 'Basso'],
#  ['Mark Bessler', 'Andrea Ziegelman', 'Alex Figueroa'],
#  ['Dana Taylor', 'Baird Ryan', 'Alexia Hamm Ryan'],
#  ['Kurt Henckels', 'Lance Lundeberg'],
#  ['William Candelaria', 'Mark Brendel', 'Yaz Hernandez', 'Basso'],
#  ['Guy Robinson', 'Elizabeth Stribling', 'Fernanda Kellogg'],
#  ['Jenny Price',
#   'Sharon Jacob',
#   'Stephanie Shuman',
#   'Gillian Miniter',
#   'Roberts'],
#  ['Cynthia Conway', 'Tom Kempner', 'Luann Blowers', 'David Blowers'],
#  ['Iffie Okoronkwo Aitkenhead', 'Agenia Clark', 'Roberts', 'Fiona Rudin'],
#  ['Jill Ross', 'Sharon Teles', 'Eby McKay'],
#  ['Kathryn Chenault', 'Carol Sutton Lewis'],
#  ['Andrea Fahnestock', 'George Hambrecht'],
#  ['Judy Angelo', 'Doug Blonsky'],
#  ['James Scott', 'Barbara Scott', 'Julie Miller', 'Kamie Lightburn'],
#  ['Gillian Miniter', 'William Zeckendorf'],
#  ['Michelle Smith', 'Tom Gold'],
#  ['Patti Harris', 'Tom Kempner', 'Veronica White'],
#  ['Sherrilyn Ifill', 'Geoffrey Canada'],
#  ['Sherrilyn Ifill', 'Lee'],
#  ['Roberts', 'Bernard Tyson', 'Gerald Adolph'],
#  ['Tyson', 'Judith Byrd'],
#  ['Philip Wells', 'Tonya Lewis Lee', 'Ted Wells', 'Byron Pitts'],
#  ['Angela Vallot', 'Roberts'],
#  ['Frank Ahimaz'],
#  ['Lee', 'Bernard Tyson'],
#  ['Lee', 'Jon Batiste'],
#  ['Janai Nelson', 'Benjamin Talton'],
#  ['Frank Ahimaz'],
#  ['Geoffrey Canada', 'Judith M. Scheide'],
#  ['Bruce Gordon', 'Tonya Lewis Lee', 'Charles Atkins'],
#  ['John Utendahl', 'Lee', 'Martin Chase'],
#  ['Jonathan Soros', 'Gwen Adolph'],
#  [],
#  ['Cheryl Brown Henderson', 'Sherrilyn Ifill', 'Osceola Brown'],
#  ['Angela Vallot', 'Gwen Adolph'],
#  ['Janet', 'Sherrilyn Ifill', 'Lisa Boykin'],
#  ['Martin Chase', 'Laurie Robinson Haden'],
#  ['Sherrilyn Ifill', 'Dwight Johnson', 'Jon Batiste', 'Marcus Miller'],
#  ['Madelaine Cohen',
#   'Kimberly Tighe',
#   'Lisa Ling',
#   'Barbara Cohen',
#   'Melissa Pordy'],
#  ['Yousaf Ali', 'Douglas Dieterich', 'Barbara Murphy', 'Alice Levine'],
#  ['Adrianne Silver', 'Susan Mark'],
#  ['Alice Levine', 'Yousaf Ali'],
#  ['Barbara Murphy', 'David Reich'],
#  ['Kimberly Tighe', 'Madelaine Cohen'],
#  ['Jane Rittmaster', 'Joan Raines', 'Vivian Farah', 'Ginny Aaron'],
#  ['Jane Whitney'],
#  ['Michael Brodman',
#   'Mary Ann McLaughlin',
#   'Kimberly Tighe',
#   'Barbara Murphy'],
#  ['Sarah Bay Williams',
#   'Paul Gachot',
#   'Richard Gachot',
#   'Dana Winslow',
#   'Emily Franchina'],
#  ['Duval Pugsley', 'Sealy Hopkinson', 'Jonathan Wehle'],
#  ['Charles Holcomb', 'Patricia Sands'],
#  ['Paul Gachot', 'Sarah Bay Williams', 'James Tiberg'],
#  ['Bart Tiernan', 'James Watson', 'Nini Tiernan'],
#  ['Richard Weir',
#   'Rita Roselle',
#   'Cynthia Jay',
#   'Julie Rinaldini',
#   'Stephen Jay',
#   'Luis Rinaldini'],
#  ['Stephen Jay'],
#  ['Michael Plackis', 'Teresa Martin', 'Robert Cooper'],
#  ['Chris Nottonson', 'Lawrence Smith', 'Ann Marie Mirabile'],
#  ['David Hidalgo',
#   'Mary Ann Tighe',
#   'Aaron Tighe',
#   'Anne-Marie Olson Kahn',
#   'Todd Kahn'],
#  ['Laurie Golub', 'Suri Kasirer'],
#  ['Kern', 'Pamela Liebman'],
#  ['David Greenbaum', 'Mary Ann Tighe', 'Glen Weiss'],
#  ['Hy Chalmé', 'Robin Chalmé', 'Ray Chalmé', 'Vanessa Chalmé'],
#  ['James Regan', 'Tom Scarangello'],
#  ['Tim', 'Jon Mechanic', 'Tommy Craig', 'Robert Knakal'],
#  ['Roxanne Donovan', 'Ted Moudis'],
#  ['Sharif El-Gamal',
#   'Sammy El-Gamal',
#   'Aziz Friedrich',
#   'Andee Radu',
#   'Daniel Parker'],
#  ['Mitti Liebersohn', 'Melissa Greenwald'],
#  ['Milo Riverso', 'Tony Schirripa'],
#  ['Charles Renfro', 'Tony Vidler', 'James Welling', 'Daniel Gortler'],
#  ['Margaret Russell', 'Henry Urbach', 'Margareth Henriquez'],
#  ['Carlos Souza', 'Charlene Ganay'],
#  ['Bonnie Morrison', 'Douglas Friedman'],
#  ['Martha Stewart', 'Charles Renfro'],
#  ['Margaret Russell',
#   'Martha Stewart',
#   'Susan Magrino Dunning',
#   'Margareth Henriquez',
#   'Reed Krakoff',
#   'Emma O’Neill',
#   'John Yunis',
#   'John Calcagno'],
#  ['Bill Katz',
#   'Bonnie Morrison',
#   'Douglas Friedman',
#   'Henry Urbach',
#   'Laurie Beckelman',
#   'James Sanders',
#   'Tony Vidler',
#   'Charles Renfro'],
#  ['Monica Rich Kosann', 'Reed Krakoff'],
#  ['Henry Urbach', 'Charles Renfro'],
#  ['Lori Tritsch', 'William Lauder'],
#  ['Martha Stewart', 'Laura Pla', 'Tomas Maier', 'Andrew Preston'],
#  ['Margaret Russell', 'Carlos Souza', 'Charlene Ganay'],
#  ['Hermes  Guillaume Seuynes',
#   'Elizabeth Stribling',
#   'Astrid Stanfield Pinel'],
#  ['Jean Shafiroff', 'Ursula Lowerre', 'Ann Van Ness', 'Kazie Harvey'],
#  ['Guy Robinson', 'Fernanda Kellogg', 'Kirk Henckels'],
#  ['Bruce Horten', 'Barbara Portago'],
#  ['Penny Grant', 'Michel Witmer'],
#  ['Laurie Bodor', 'William Ivey'],
#  ['Cole Rumbough', 'Bettina Bennett'],
#  ['Irene Aitken'],
#  ['Odile Schiétère-Longchampt', 'Timothy Corrigan'],
#  ['Alex Donner', 'Jean Shafiroff', 'Geoffrey Bradfield'],
#  ['Ann Van Ness', 'Elizabeth Stribling', 'Patricia Shiah'],
#  ['Roy Keane'],
#  ['Silvina Leone', 'Ben Aguilar'],
#  ['Charles Revson'],
#  ['Kate Coyne', 'Robert Liberman', 'Libby Monaco'],
#  ['Arriana Boardman', 'Flo Fulton Miller'],
#  ['Kristin Fisher Allen',
#   'Virginia Wettlaufer',
#   'Lily Maddock',
#   'Travis Acquavella'],
#  ['Robert Hart'],
#  ['Ann Hohenhaus', 'Michael Heaner'],
#  ['Dan Galpern', 'Alice Rosenwal', 'Michael Borofsky', 'Jay Galluzzo'],
#  ['Michaela Pereira'],
#  ['Joseph Belluck'],
#  ['Christine Schott Ledes', 'George Ledes', 'Jackie Norden'],
#  ['Richard Ledes', 'Jean Shafiroff'],
#  ['Cole Rumough', 'Kick Kennedy'],
#  ['Brian Maher', 'Ann Jensen', 'Eric Jensen'],
#  ['Nicole DiCocco', 'Alex Donner'],
#  ['Consuelo Vanderbilt Costin', 'Gregory Speck'],
#  ['Travis Acquavella',
#   'Carolina Neufville',
#   'Eleanor Ylvisaker',
#   'Martha Glass',
#   'Monique Lhuillier',
#   'Shabnam Henry'],
#  ['Dani Stahl', 'Eleanor Ylvisaker', 'Shoshanna Gruss', 'Patricia Lansing'],
#  ['Cynthia Cook Smith'],
#  ['Alex Acquavella', 'Mollie Ruprecht'],
#  ['Hadley Reynolds', 'Sara Peters', 'Clare McKeon'],
#  ['Monique Lhuillier', 'Gretchen Gunlocke Fenton'],
#  ['Natalie Leeds Leventhal', 'Nina Garcia'],
#  ['Wes Gordon', 'Paul Arnhold'],
#  ['Eleanora Kennedy', 'Anna Kennedy Safir'],
#  ['Jenny Galluzzo', 'Charlotte Ronson'],
#  ['Kelly Turlington Burns', 'Brian Burns'],
#  ['Ferebee Taube'],
#  ['Amanda Meigher', 'Nina Carbone'],
#  ['Sarah Lanni', 'Mollie Ruprecht'],
#  ['Joseph Singer', 'Mish Tworkowski', 'Tom Bugbee'],
#  ['Monique Lhuillier', 'Jessica Sailer Lith', 'Tom Bugbee'],
#  ['Carolina Neufville', 'Alvin Valley'],
#  ['Monique Lhuiller', 'Bronson Van Wyck'],
#  ['Jose Luis Los Arcos'],
#  ['Martha Sharp', 'Leslie Heaney'],
#  ['Nick Acquavella', 'Dixon Boardman'],
#  ['Kim Flaster', 'Shoshanna Gruss', 'Monique Lhuillier'],
#  ['Eugenie Niven Goodman', 'Martha Glass'],
#  ['Martha Glass', 'Lisa Errico', 'Carolina Neufville'],
#  ['Edward Barsamian'],
#  ['Jamie Niven', 'Lela Rose'],
#  ['Barret Swatek', 'Leslie Finerman'],
#  ['Alexandra Lind Rose', 'Jackie Astier', 'Emilia Fanjul Pfeifler'],
#  ['Carla Darlington', 'Zita Davisson'],
#  ['Judith Oringer', 'Andrew Kotchoubey'],
#  ['Nancy Gehman', 'Irene Goodkind', 'Jerry Gehman'],
#  ['Sonja Morgan', 'Jay Paul'],
#  ['Charlie Scheips', 'Didi'],
#  ['Miles Morgan', 'Kaleeta Doolin', 'Alan Govenar'],
#  [],
#  ['Charlie Scheips', 'Elaine Uzan Leary'],
#  ['Victoria Vicunia', 'Miles Morgan', 'Sonja Morgan'],
#  ['Jean Shafiroff', 'Sonja Morgan', 'Nancy Gehman'],
#  ['John Mojdehi', 'Sonja Morgan'],
#  ['Danny DiVella',
#   'Steve Millington',
#   'Robyn Levy-Wolf',
#   'Mario Moise',
#   'Michael McCarty'],
#  ['Ruth Westheimer', 'Laurie Tisch'],
#  ['Nancy Spears', 'Sissy Biggers'],
#  ['Sean Kelly', 'Cecile Panzieri', 'Lauren Kelly'],
#  ['Paul Karian'],
#  ['Kim McCarty', 'Susan Magrino Dunning', 'Allyn Magrino Holmberg'],
#  ['Susan Silver', 'Joel Wachs'],
#  ['Rikki Klieman', 'Steve Millington'],
#  ['Liz Byrne', 'Gerry Byrne'],
#  ['Joel Schnell', 'Lynn White'],
#  ['Joan Kron', 'Jonathan Marder'],
#  ['Dagny Corcoran'],
#  ['Scott Merkin', 'Susan Blond'],
#  ['Shari Rollins', 'Rick Friedberg'],
#  ['Matt Blank'],
#  ['Hilary Gumbel', 'Bryant Gumbel'],
#  ['John Hart', 'Nicolle Meyer'],
#  ['Daniel Benedict'],
#  ['Kath Hinton'],
#  ['Edward Klein'],
#  ['Joanna Coles', 'Peter Godwin'],
#  ['John Jacobson', 'Betsy Perry'],
#  ['Annik Wolf', 'Michael Wolf'],
#  ['Michelle Coppedge', 'Jamie MacGuire'],
#  ['Jay McInerney', 'Anne Hearst McInerney'],
#  ['David Hryck', 'Joan Jedell'],
#  ['Alexander Julian', 'Megan Julian'],
#  ['Neal Fox', 'Martha Kramer'],
#  ['James Crump', 'Ronnie Sassoon'],
#  ['Robin Wolf', 'Jamie Levy'],
#  ['Florence Fabricant', 'Richard Fabricant', 'Jerry lla Femina', 'Judy Licht'],
#  ['Roberta Allen', 'Lisa Birnbach', 'LeFrak Calicchio'],
#  ['Wendy Stark', 'Geroge Farias', 'Amy Fine Collins'],
#  ['John Hart', 'Nicolle Meyer'],
#  ['Robin Wolf', 'Philippe Solomon', 'Paula Solomon'],
#  ['Tim Zagat', 'Nina Zagat'],
#  ['Ben Slepian', 'Thom Filicia', 'Margo Slepian', 'Greg Calejo'],
#  ['John Koblin', 'Katie Rosman'],
#  ['Michael McCarty', 'Connie Anne Phillips', 'Armando Ruiz'],
#  ['Michelle Fizer-Peterson', 'Charles Grodin', 'Julio Peterson'],
#  ['Patrick Murphy', 'Mary Murphy'],
#  ['Ed Rollins', 'Shari Rollins'],
#  ['Holmberg', 'Allyn Magrino Holmberg'],
#  ['Jamie Niven', 'Mike Goldberg', 'Linda Fairstein', 'David Patrick Columbia'],
#  ['Sharon Bush', 'Oscar Plotkin'],
#  ['Dick Soloway', 'Donna Soloway'],
#  ['Michael McCarty', 'Sara Beth Shrager'],
#  ['George Farias', 'Wendy Stark'],
#  ['Claire Mercury'],
#  ['Missy Falchi', 'Carlos Falchi', 'Mickey Ateyeh'],
#  ['Felicia Taylor', 'Reed Covone'],
#  ['Paul Chapman', 'Camila Savia'],
#  ['Jay Kriegel', 'Tim Zagat', 'Nina Zagat', 'Gordon Davis'],
#  ['Katie Lee Pollack', 'Stephanie Sporn'],
#  ['Diane Clehane', 'Anne Fulenwider'],
#  ['Paul Amann', 'Joe Fitzsimmons'],
#  ['Stan Parish'],
#  ['Barry Frey'],
#  ['Carol Austell', 'Jim Mitchell'],
#  ['Wendy Moonan', 'Rhett'],
#  ['Leslie Stevens', 'Nina Burleigh', 'Bobby Freidman', 'Bob Shaye'],
#  ['Gregoire Vogelsang'],
#  ['Roger Smith', 'Bob Shaye'],
#  ['Monie Begley', 'Sessa Richthofen'],
#  ['Alex Newbold', 'Kristen Kirkland'],
#  ['Kirsten Fleming', 'Mark Whitaker', 'Monie Begley', 'Roger Moore'],
#  ['Oliver Coleman', 'Emily Coleman'],
#  ['Michael McCarty', 'Clancy McCarty', 'Chaz McCarty', 'Kim McCarty'],
#  ['Rhett Austell', 'Michael McCarty', 'Carol Austell', 'Steve Millington'],
#  ['Griffin Frazen', 'Jed Weisman', 'Hannah Glazebrook', 'Anna Gray'],
#  ['Alexandra Kovalyuk', 'Gregoire Vogelsang'],
#  ['Richard Johnson', 'Sessa Richthofen'],
#  ['Giorgiva', 'Joe Rayo'],
#  ['Jerry Inzerillo', 'Kevin Ryan', 'Tom Rogers'],
#  ['Jane Notar', 'Richie Notar', 'Jennifer Gould'],
#  ['Dan Abrams', 'Lynn Sherr', 'Peggy Siegal'],
#  ['Amy Kliger', 'Jack Kliger', 'Michael McCarty'],
#  ['James Dunning', 'Michael McCarty'],
#  ['Griffin Dunne', 'Joanna Coles', 'Peter Godwin'],
#  ['Stuart Sundlun', 'Jennifer Heidi'],
#  ['Richard Johnson', 'David Kuhn', 'Leslie Stevens', 'Kevin Thompson'],
#  ['Cheri Kaufman', 'Sharon Bush', 'Janna Bullock'],
#  ['David Hyrke', 'Dora Tomanovich'],
#  ['Audrey Gruss', 'Susan Gutfreund'],
#  ['Janna Bullock', 'Karen Klopp'],
#  ['Sirio Maccioni', 'Ruth Westheimer'],
#  ['Mush Katkol', 'Sharon Bush', 'Brian Murphy'],
#  ['Kamie Lightburn', 'Bill Sclight', 'Paula Bacchini'],
#  ['Penelope Collins', 'Christine Triant'],
#  ['Marcella Martin', 'Billy Lerner'],
#  ['Natalie Anise', 'Eddie Trunk'],
#  ['George Chrisafis'],
#  ['Mike Scottie', 'John Withrow'],
#  ['Fara Hain Zerto', 'Cathy Andersen'],
#  ['Martin Sorrell', 'Charlie Rose'],
#  ['Ronald Perelman', 'Charlie Rose', 'Martin Sorrell', 'Robert K. Kraft'],
#  ['Allen Popowitz',
#   'Don Mattingly',
#   'Dorine Gordon',
#   'Keith Hernandez',
#   'Bob Costas',
#   'Franco Harris'],
#  ['Dorine Gordon', 'Jennifer Steinbrenner Swindal', 'Liz Martin'],
#  ['Kevin Brown Thompson', 'Jeter'],
#  ['Kevin Brown Thompson', 'Eddie Redmayne'],
#  ['Tamsen Fadal',
#   'Lois Braverman',
#   'Suzanne Murphy',
#   'Javier Gomez',
#   'Martha Fling'],
#  ['Laurie Sprayregen', 'Alice Netter', 'James Sprayregen'],
#  ['Michele Scheinkman', 'Lois Braverman', 'Marie Wilson'],
#  ['Arnold Syrop', 'Linda Dishy'],
#  ['Tamsen Fadal', 'Chris Gillespie', 'Martha Fling'],
#  ['Javier Gomez', 'Camilla Barungi'],
#  ['Kristy Rao', 'Javier Gomez'],
#  ['Lois Braverman', 'Andrew Solomon'],
#  ['Dorimar Morales', 'Erika Klein'],
#  ['Andrew Malcolm', 'Dan Bena'],
#  ['Bryan R. Murphy', 'Brooke Baran'],
#  ['Gala Co'],
#  ['Brooke Baran', 'Leslie Zeller', 'Tyrone Hodge', 'Barbara Baran'],
#  ['Pierce Brosnan', 'Harry Connick'],
#  ['Pierce Brosnan', 'Harry Connick', 'Brooke Goodman Cohen'],
#  ['Chet Burros', 'Mara Sandler', 'Ricky Sandler'],
#  ['Chris Salgardo', 'Carol Hamilton'],
#  ['Audra Moran', 'Pierce Brosnan', 'Brooke Goodman Cohen', 'Chris Salgardo'],
#  ['Nick Loeb', 'Kat Cohen'],
#  ['Audra Moran', 'Harry Connick', 'Sol Schreiber'],
#  ['Kat Cohen', 'Dori Cooperman'],
#  ['Harry Connick', 'Pierce Brosnan', 'Chris Salgardo'],
#  ['Sherry Jacobson', 'Harry Connick', 'John Hansbury', 'Brooke Goodman Cohen'],
#  ['Ed Labaton', 'Audra Moran', 'Sol Schreiber'],
#  ['Catherine Malandrino', 'Kelly Rutherford'],
#  ['Kara Gordon', 'Vita Giordano'],
#  ['Lila Nejad', 'Taryn Manning'],
#  ['Lisa Lampanelli', 'Harry Connick'],
#  ['Lieba Nesis', 'Joan Jedell', 'David Hryck'],
#  ['Rob Tilberis', 'Jeanette Chang', 'Chris Tilberis'],
#  ['Alison Brod', 'Maneesh Goyal'],
#  ['Liz Margolies'],
#  ['Dani Stahl',
#   'Charlotte Ronson',
#   'Katie Zorn',
#   'Chiara Rege',
#   'Jennifer Liang',
#   'Hilary Koyfman'],
#  ['Alexis Preston', 'Katie Zorn', 'Nicole Veras'],
#  ['Jane Pellietere', 'Kenn Dudek', 'Mary Ingriselli'],
#  ['Ben Howe', 'Lou Howe', 'Luca Borghese'],
#  ['Dick Zorn', 'Ilene Wetson'],
#  ['Bill Murphy', 'Justyna Zajac'],
#  ['Graziano Boni', 'Valerie Boni', 'Cliff Brokaw', 'Mark Gilbertson'],
#  ['Jose Luis Guerra', 'Florence Peyrelongue'],
#  ['Katie Tozer', 'Jack Lynch', 'Gillian Boyer'],
#  ['John Rustum', 'Shannon Henderson', 'Todd Henderson'],
#  ['Michael Clofine', 'Angela Clofine'],
#  ['Bill Manger', 'Elizabeth Pyne'],
#  ['Dick Zorn', 'Franny Zorn', 'Katie Zorn', 'Lee Huebner'],
#  ['Jo Garst', 'Tracy Lindwall'],
#  ['Tracey Huff', 'Joseph Brandt', 'Carol Brandt'],
#  ['Elise McLean', 'Megan Henze', 'Fritz Franz', 'Chrissy Franz'],
#  ['Benjamin Zimbric'],
#  ['Violetta Weddepohl', 'Nick Raynes', 'Lil Phillips'],
#  ['Alex Lipman', 'Sarah Simmons', 'Brooke Mountain', 'Asher Lipman'],
#  ['Megan Savage', 'Tyler Gaffney'],
#  ['Ali Carter', 'Virginia Tracey', 'Kate Brecht'],
#  ['Carrie Howe', 'Lou Howe', 'Ellen Howe', 'Ben Howe'],
#  ['Mo Koyfman', 'Hilary Koyfman'],
#  ['Angela Clofine'],
#  ['Sloane Mikesell',
#   'Amanda Schumaker',
#   'Jamie Birkenhead',
#   'Richard Birkenhead'],
#  ['Jonathan Berger'],
#  ['Shari Lusskin'],
#  ['Warren Tye', 'Giusi Cennamo', 'Ben Draper', 'Jessica Caetano'],
#  ['Liz Anderson', 'Rema Parachini'],
#  ['Ben Howe', 'Helen Pennoyer', 'Daisy Keevil', 'Luca Borghese'],
#  ['Alexandra Fisher', 'Phil Fisher', 'Diane Chachas'],
#  ['Danielle Goldstein', 'Richard Donnell', 'Leila Feinberg'],
#  ['Ecaterina Andreev', 'Warren Tye', 'Giusi Cennamo'],
#  ['Katherine Todd', 'Jaimee Zanzinger'],
#  ['Michael Pierson', 'Annette Tapert Allen', 'Lou Howe'],
#  ['Mark Gilbertson', 'Kate Allen'],
#  ['Kamie Lightburn', 'Scott Anderson'],
#  ['Olda FitzGerald', 'Susan Richardson', 'Kathrine Richardson'],
#  ['Beth Dater', 'Michael Kerrigan'],
#  ['Alexandra Schlesinger', 'Kenneth Jay Lane', 'Olda FitzGerald'],
#  ['Sean Reynolds', 'Paularmott', 'Donough Cahill', 'Kyra Cheremeteff'],
#  ['Jose Aguire'],
#  ['Jill Donoghue', "Robert O'Byrne"],
#  ['Bob Dowling', 'Steven Stolman', 'Michael Kerrigan', 'Rich Wilke'],
#  ['Robert Fox', 'Anya Fox'],
#  ['James Anderson', 'Ivana Lowell', 'Steven Gambrel'],
#  ['Angus Wilke', 'Cynthia Ryan'],
#  ['Christopher Monkhouse', 'William Laffan'],
#  ['Maribeth Welsh', 'Tom Quick'],
#  ['Scott Seydel',
#   'Pat Mitchell',
#   'Elianne Ramos',
#   'Sheila Johnson',
#   'Julie Burton'],
#  ['Clive Davis', 'Lesley Gore'],
#  ['David Corn', 'Jessica Valenti', 'Elizabeth Plank', 'Rachel Sklar'],
#  ['Bonnie Schaefer', 'Robin Morgan'],
#  ['Jewelle Bickford', 'Lauren Embrey', 'Sally Kohn'],
#  ['Julie Burton', 'Carol Jenkins', 'Carolyn Maloney'],
#  ['Phil Donahue', 'Marlo Thomas', 'Robin Morgan'],
#  ['Roger Hickey', 'David Corn', 'Julie Burton'],
#  ['Sady Doyle', 'Elianne Ramos', 'Lindy West'],
#  ['Steven Swig', 'Mary Swig'],
#  ['Vanessa  Luca', 'Elianne Ramos', 'Juile Burton'],
#  ['Bob Peterson', 'Katie Couric', 'Marlo Thomas'],
#  ['Katie Couric', 'Barbara Walters'],
#  ['Margaret Smith',
#   'Susan Burden',
#   'Duane Hampton',
#   'Patrick Murphy',
#   'Kathryn Cashman',
#   'Sally Phipps',
#   'Paul Powers',
#   'Beth Reifers',
#   'David Meneret',
#   'Mary Connelly',
#   'Gib Dunham',
#   'Jeff Weber',
#   "Lindsay O'Reilly"],
#  ['David Marcus',
#   'Eileen Casey',
#   'Roderick Jenkins',
#   'Len McNally',
#   'Pat Jenny',
#   'Lorie Slutsky',
#   'Irfan Hassan'],
#  ['David Meneret'],
#  ['Chairs Margaret', 'Ian Smith'],
#  ['Jenny Rodriguez',
#   'Norma Negron',
#   'Carol Massa',
#   'George Davis',
#   'Sarah Petit',
#   'Rita Trapner',
#   'Anne Wild'],
#  ['Sharon Casdin', 'Mary Van Pelt', 'Sara Hobel'],
#  ['Sherri Stephenson', 'Monica Bolstad'],
#  ['Bronson Van Wyck', 'Coco Kopelman'],
#  ['Jean Shafiroff', 'Nancy Gehman'],
#  ['Alison Strong', 'Jill Ross'],
#  ['Andrea Fahnestock', 'Liz Kogen'],
#  ['Anna Safir', 'Eleanora Kennedy'],
#  ['Grace Meigher', 'Mark Gilbertson', 'Warrie Price'],
#  ['Barbara Paul Robinson',
#   'Louis Bauer',
#   'Mark Fisher',
#   'Marechal Brown',
#   'Tom Smarr'],
#  ['Jack Lynch', 'Barbara McLaughlin'],
#  ['Loren Taufield', 'Hilary Block', 'Helen Fitzgerald'],
#  ['Kamie Lightburn', 'Francis Schultz'],
#  ['Linda Fraser', 'Melanie Wambold'],
#  ['Mary Van Pelt', 'Melanie Chisholm'],
#  ['Lindsey Pryor', 'Lucy Lamphere', 'Sheila Stephenson', 'Betsy Bacon'],
#  ['Nikki Brown', 'Kate Hemphill'],
#  ['Maria Hernandez', 'Douglas Blonsky', 'Kamie Lightburn'],
#  ['Nina Griscom', 'Mark Gilbertson'],
#  ['Marianne Engle', 'Susi Wunsch', 'Cecilia Dupire'],
#  ['Holly Hunt', 'Kamie Lightburn', 'Stephanie Loeffler'],
#  ['Nancy Mortimer', 'Jessica Tcherepnine', 'Anne Ekstrom'],
#  ['Sheila Stephenson', "Lily O'Boyle"],
#  ['Natalie Pray', 'Helen Fitzgerald', 'Lucy Day', 'Sharon Casdin'],
#  ['Ursula Lowerre', 'Nancy Paduano'],
#  ['Rochelle Ohrstrom', 'Liz Peek', 'Lucy Lamphere'],
#  [],
#  ['Neil Cavuto', 'Peter Mayer', 'Jon Huntsman', 'Abby Huntsman'],
#  ['Pete Peterson', 'Michael Peterson', 'Jon Huntsman'],
#  ['Sandi Mendelson', 'Christopher Cerf', 'Lynn Sherr'],
#  ['Mary Kaye Huntsman', 'Jon Huntsman', 'Abby Huntsman'],
#  ['Jon Huntsman', 'Jeff Greenfield'],
#  ['Vicky Ward', 'Richard Cohen'],
#  ['Rudy Sotolongo',
#   'Wayne Reaud',
#   'Jon Huntsman',
#   'Larry Tillury',
#   'Paul Huntsman'],
#  ['Glenn Horowitz', 'Tracey Jackson'],
#  ['Betsy Gotbaum', 'Mitch Rosenthal'],
#  ['Wayne Reaud', 'Ben Barnes'],
#  ['David Peterson', 'Peter Cary Peterson', 'Paige Peterson'],
#  ['Amanda Low',
#   'Stacy Pinelli',
#   'Elyse Fuerth',
#   'Barbara Barbera',
#   'Holly Peterson',
#   'Maria Vecchiotti',
#   'Cathy Trentalancia'],
#  ['SAH Trustees Elsie Aidinoff',
#   'Amanda Low',
#   'Pete Eikenberry',
#   'Mimi Saltzman',
#   'Maria Vecchiotti',
#   'Jonathan Stearns',
#   'Holly Peterson',
#   'Dorian Brown'],
#  ['Elisa Istueta',
#   'Jennifer Marrus',
#   'Mary Judelson',
#   'Holly Peterson',
#   'Ritchie Howe'],
#  ['Holly Peterson', 'Ray Cameron'],
#  ['Patty Sacks', 'Elyse Fuerth', 'Vanessa Fuerth', 'Valerie Goldfein'],
#  ['Pat Schifke', 'Maria Vecchiotti', 'Donna Golkin'],
#  ['Joan Saltzman'],
#  ['Sue Davies', 'Elsie Aidinoff'],
#  ['Alexis Thomason'],
#  ['SAH Student', 'Martine Rubenstein'],
#  ['Lisa Plepler'],
#  ['Jim Coleman', 'Cynthia Ott'],
#  ['David Orentreich', 'Marina Killery'],
#  ['Amy Hoadley'],
#  ['Fred Spencer', 'Bianca Nikic'],
#  ['Stephen Westerfield',
#   'Kimberly Hart',
#   'Michael Barlow',
#   'Bryan Sherman',
#   'Grace Johnson'],
#  ['Alison Minton', 'Bob Stumo', "Anne D'Innocruzio"],
#  ['Megan Meade', 'Chris Lipuia', 'Adam Brenner', 'Charlie Amber'],
#  ['Wendy Carduner', 'Kathleen Giordano'],
#  ['Jeffrey Borenstein', 'Herbert Pardes', 'Mehmet C. Oz'],
#  ['Eric Kandel', 'Jeffrey Borenstein', 'Mehmet Oz'],
#  ['John Golden', 'Suzanne Golden', 'Carole Mallement'],
#  ['Ronald Abramson', 'Anne Abramson', 'Eve Novick'],
#  ['Mehmet Oz', 'Ellen Levine', 'Richard Levine'],
#  ['Peter Sellars', 'Elihu Rose'],
#  ['John Guare', 'Chatfield Taylor', 'Peter Sellars'],
#  ['John Guare', 'Chatfield Taylor', 'Peter Sellars'],
#  ['Sheba Jafari'],
#  ['Jim Seger', 'Lissa Frenkel'],
#  ['Elizabeth Kahane', 'Shirley Madhere'],
#  ['Olivia Flatto', 'Alex Poots', 'Heidi McWilliams', 'Adrienne Arsht'],
#  ['Elizabeth Kahane', 'Rebecca Robertson', 'Shirley Madhere'],
#  ['Libby Ellis', 'Adrian Ellis'],
#  ['Randy Kemper', 'Tony Ingrao'],
#  ['Wendy Belzberg', 'Jenny Kassanoff'],
#  ['Marjorie Reed Gordon', 'Ellery Gordon'],
#  ['Elihu Rose', 'Susan Rose', 'Isabelle Rose', 'Jeffrey Fagen'],
#  ['Joanne Ellis', 'Scott Waddell'],
#  ['Monique Van Vooren', 'Geoffrey Bradfield'],
#  ['Michael Feinstein', 'Cathie Black', 'Tom Harvey', 'Adrienne Arsht'],
#  ['Juliana May', 'Amy Silverman'],
#  ['Ida Liu', 'Michael Rockefeller', 'Tara Rockefeller'],
#  ['Raj Prakash', 'Stacey Alvarez'],
#  ['Juliana May', 'Jonathan May', 'Amy Silverman', 'Jeffrey Silverman'],
#  ['Leslie Bains', 'Harrison Bains'],
#  ['Alan Levenstein', 'Gail Levenstein'],
#  ['Karen Ackman', 'Bill Ackman'],
#  ['Tamara Bernstein', 'Brad Bernstein'],
#  ['Bonnie Comley', 'Stewart Lane', 'Leah Lane'],
#  ['Steven Brill', 'Cynthia Brill'],
#  ['Jamee Gregory', 'Peter Gregory'],
#  ['Michael Shnayerson', 'Gayfryd Steinberg'],
#  ['David Wassong', 'Cynthia Clift', 'Alyssa Fanelli', 'Jeffrey Hirsch'],
#  ['Nancy Offit', 'Morris Offit', 'Nancy Marks'],
#  ['Madison J Papp', 'Justin Kush'],
#  ['Lisa Ehrenkranz', 'Sandy Ehrenkranz'],
#  ['Kathy Steinberg', 'Veronica Kelly'],
#  ['Michael Barclay', 'Inga Kozel'],
#  ['James Bassett', 'Bree Jeppson'],
#  ['Paul', 'Coralie Charriol Paul'],
#  ['Sanford Smith', 'Jill Bokor'],
#  ['Adam Schlossinger', 'Natasha Schlossinger', 'Nanna Stern', 'Dan Stern'],
#  ['Amy Galanos', 'Nanna Stern'],
#  [],
#  ['Julie Macklowe', 'Billy Macklowe'],
#  ['Stan Warshawsky', 'Mort Zuckerman'],
#  ['Margot Steinberg', 'Stan Harrison'],
#  ['Mary Ellen Oldenburg',
#   'Inger Elliott',
#   'Janet Ross',
#   'Elizabeth Strong-Cuevas'],
#  ['Diana Revson',
#   'Tripp Revson',
#   'Kylie Halperin',
#   'Alex Revson',
#   'Alexis Powers'],
#  ['Terry Crosby'],
#  ['Zoe Bullock', 'Janna Bullock'],
#  ['Jamie Tisch'],
#  ['Laura Ramsey', 'Rachel Jacobellis'],
#  ['Johnnie Planco', 'Monique Vooren', 'Geoffrey Bradfield'],
#  ['Heidi McWilliams', 'Chuck Royce'],
#  ['George Farias', 'Bettina Zilkha', 'Ann Wolf', 'Mathew Wolf'],
#  ['John Fiscora', 'Katherine Todd'],
#  [],
#  ['Joanne Ellis', 'Scott Waddell'],
#  ['Andy Winer', 'Liz Ward', 'Natalie Wiegenfeld', 'Yoav Wiegenfeld'],
#  ['Jill Lloyd', 'Isabelle Harnoncourt', 'Noreen Buckfire'],
#  ['Lorri Ahl', 'Michael Edsall'],
#  ['Diane Lippert',
#   'Justin Kush',
#   'Margaret Pennoyer',
#   'Angelina Lippert',
#   'Hugh MacKay'],
#  ['Barbara Tober',
#   'Donald Tober',
#   'Saul',
#   'Andrew Saul',
#   'Mindy Papp',
#   'Matthew Smyth'],
#  ['Chris Larson', 'Mary Kush', 'Ed Sumpter', 'Marcella Ciceri', 'Gus Davis'],
#  ['Cathie Black', 'Tom Harvey', 'Adrienne Arsht'],
#  ['Richard Meyer', 'Karon Meyer'],
#  ['Christian Gudefin', 'Marie Noel Pierce'],
#  ['Alyssa Fanelli', 'Cynthia Clift', 'Lesley Vecsler', 'Priscilla Zoullas'],
#  ['Sheila Stephenson', 'George Stephenson'],
#  ['Sherri Geldin'],
#  ['Sheba Jafari'],
#  ['James Nguyen', 'Alexander Gottlieb'],
#  ['Gwen Norton', 'Sam Claiborne'],
#  ['Thelma Golden', 'Kate'],
#  ['Colin Callender', 'Julie Taymor'],
#  ['Mira Nair', 'Joe Reece'],
#  ['Susan Rose', 'Cameron Carpenter'],
#  ['McGee Diana Revson', 'Joyce Cowin'],
#  ['Paul Travis', 'Eric Rudin'],
#  ['Tom Pulling', 'Eileen Pulling'],
#  ['Sandy Farkas', 'Andrew Farkas'],
#  ['Alexis Powers',
#   'Alex Revson',
#   'Charles Revson',
#   'Diana Revson',
#   'Kylie Halperin',
#   'Tripp Revson'],
#  ['Peter Nitze', 'Susan Nitze'],
#  ['Fran Weissler', 'Fred Shuman', 'Stephanie Shuman'],
#  ['Samantha Rudin Earls', 'George Farias', 'Ophelia Rudin'],
#  ['Raj Prakash', 'Stacey Alvarez'],
#  ['Frank Ahimaz', 'James Reginato', 'Steve Barr'],
#  ['Pedro Gonzales', 'Maria Caso'],
#  ['David Halberstadt'],
#  ['Richard Gaddes', 'Daisy Soros'],
#  ['Jeff Arnstein', 'Pat Papachristidis'],
#  ['Charlotte Mittenthal', 'Tilly Moross'],
#  ['Frank Morgan', 'Thomas Teeple', 'John David Willingham'],
#  ['Bill Rudin', 'Scott Nelson'],
#  ['Isabelle Harnoncourt', 'Richard Feigen'],
#  ['Alex Navab', 'Mary Katheryn'],
#  ['Michael Wise'],
#  ['Norton Belknap', 'Marjorie Hart', 'Gurnee Hart'],
#  ['Edmee Firth', 'Andrew Farkas'],
#  ['Barbara Gundlach', 'Andrew Gundlach', 'Shirin Wolfen'],
#  ['Cecelia Alemani', 'Timothy Quinlan'],
#  ['Annie Taube', 'Eleanor Ylvisaker'],
#  ['Liz Bickley', 'Julie Geden', 'Kirsten Reoch'],
#  ['Alexia Hamm Ryan', 'Natalie Kaplan'],
#  ['Andrew Heaney', 'Andrew Georges', 'Leslie Heaney'],
#  ['Ara Hovnanian', 'Elizabeth Kergolay'],
#  ['Betsy Pitts'],
#  ['Bruce Addison', 'Evelyn Tompkins'],
#  ['Carol Mack'],
#  ['Chris Meigher', 'Mary Hilliard', 'Bill McKnight'],
#  ['Daisy Kanavos'],
#  ['Daumann', 'Nina Griscom'],
#  ['Karl Wellner'],
#  ['Frances Schultz', 'Nina Griscom'],
#  ['Grace Meigher', 'Brad Comisar'],
#  ['Julian Gratry', 'Jamie Tisch'],
#  ['Kara Ross', 'Rachel Hovnanian', 'Wendy Carduner'],
#  ['Kate Allen', 'Jennifer Oken'],
#  ['Kirk Henckels', 'Larry Graev'],
#  ['Kari Tiedemann'],
#  ['Mag Braff', 'Leslie Stevens', 'Chappy Morris'],
#  ['Mark Gilbertson', 'Barbara Tober'],
#  ['Mark Gilbertson', 'Bronson Van Wyck', 'Zani Gugelmann'],
#  ['Michael Comminotto', 'Basso'],
#  ['Nina Richter', 'Terry Fritzgerald'],
#  ['Pauline Pitt', 'Jerry Seay', 'Fernanda Kellogg'],
#  ['Whitney Fairchild', 'Scott Currie'],
#  ['Stephanie Foster', 'Pam Owen'],
#  ['Richard Cohen', 'Vicky Ward'],
#  ['Richard Johnson', 'Vicky Ward'],
#  ['Ellsworth Kelly'],
#  ['Bonnie Burnham', 'Mica Ertegun', 'Ellsworth Kelly', 'Mary McFadden'],
#  ['Ashton Hawkins', 'Patty Tang', 'John Hawkins', 'Peter Kimmel'],
#  ['Fernanda Kellogg', 'Kirk Henckels'],
#  ['Anne Mai', 'Lebiba Ali'],
#  ['Connie Hildesley', 'Alex Gregory', 'Linda Wachner'],
#  ['Ashton Hawkins', 'Joan Hardy Clark', 'Peter Duchin'],
#  ['Laura Sico', 'Natalie Kaplan'],
#  ['Manuela Hoelterhoff', 'Ildiko Butler'],
#  ['Gary Pudney', 'Amy Lemons-Sutton', 'Kenny Lane'],
#  ['Lilla Ohrstrom', 'Chris Ohrstrom'],
#  ['Jean-Michel Placent', 'Felicia Taylor'],
#  ['Tyler Gaffney', 'Todd Yannuzzi'],
#  ['Alice Walton', 'Linda Ferber'],
#  ['Robert Couturier', 'Irith Landeau', 'Mercedes Bass', 'Jim Zirin'],
#  ['Barbara Goldsmith', 'Lester Weingarten'],
#  ['Roberta Sandeman', 'Peter Pennoyer'],
#  ['Ann Madonia', 'Suzanne Clary'],
#  ['Christopher Walling', 'Casey Kohlberg'],
#  ['Paul Beirne', 'Suzanna Cole Kohlberg'],
#  ['James Reginata',
#   'Alison Gingeras',
#   'A. M. Homes',
#   'Jack Bankowsky',
#   'Charlotte Birnbaum',
#   'Nicholas Cullinan'],
#  ['Cynthia Frank', 'Muffie Potter Aston', 'Alexia Hamm Ryan', 'Karen Zucker'],
#  ['Trish Carroll',
#   'Hilary Dick',
#   'Courtney Moss',
#   'Sallie Giordano',
#   'Jennifer Creel'],
#  ['Madeline Weinrib', 'Jacqueline Schnabel'],
#  ['Grace Meigher', 'Jamee Gregory'],
#  ['Muffie Potter Aston', 'Martha Glass', 'Judy Cox'],
#  ['Mario Buatta', 'Michael Boodro'],
#  ['Eleanor Ylvisaker', 'Beth Blake Day'],
#  ['Christopher Spitzmiller', 'Sam Allen'],
#  ['Ernest la Torre', 'Michael Boodro', 'Barbara Friedmann'],
#  ['Martha Sharp', 'Julie Miller'],
#  ['Teresa Colley', 'Cathy Nassau', 'Karen Klopp', 'Susy Schieffelin'],
#  ['Blaine'],
#  ['Paula Abdul', 'Michael Dameski'],
#  ['Michele Riggi', 'Alexander Dube'],
#  ['Joe Tremaine', 'Janice Galli Becker'],
#  ['James Earl Jones', 'Angela Lansbury'],
#  ['Michele Riggi', 'Joe Tremaine'],
#  ['Cynthia Fischer', 'Angela Lansbury', 'Cynthia Gregory'],
#  ['Susan Gutfreund', 'Larry Kaiser'],
#  ['Adam Pollet', 'Jennifer Becker Pollet', 'Stuart Becker'],
#  ['Victor Elmaleh', 'Sono Osato'],
#  ['Janice Galli Becker', 'Stuart Becker'],
#  ['Barbara Taylor Bradford', 'Robert Bradford'],
#  ['Edgar Batista', 'Margo Langenberg', 'Edward Callaghan'],
#  ['Prima', 'Cynthia Gregory', 'Ann Marie Angelo'],
#  ['Alex Dube'],
#  ['Candace Gonzalez', 'Ann Van Ness', 'Caroline Lieberman'],
#  ['Jean Shafiroff', 'Lucia Hwong Gordon'],
#  ['Lynn Sherr', 'John McEnroe'],
#  ['Valerie Ohrstrom',
#   'Kamie Lightburn',
#   'Nyssa Kourakos',
#   'Karen Thornwell',
#   'Neda Navab',
#   'Lynn Sherr'],
#  ['Judy Hart Angelo', 'Mary Pat Christie', 'Elaine Langone'],
#  ['Valerie Ohrstrom', 'Neda Navab', 'Nyssa Kourakos', 'Kamie Lightburn'],
#  ['Karen LeFrak', 'Gillian Miniter', 'Hilary Geary Ross'],
#  ['Kate Gellert', 'Nancy Missett'],
#  ['Sharon Jacob'],
#  ['Lise Evans', 'Alexia Leuschen'],
#  ['Luanne Blowers', 'Sheila Labrecque'],
#  ['Noreen Buckfire', 'Paternó-Castello'],
#  ['Suzanne Cochran', 'John McEnroe', 'Lynn Sherr', 'Tom Kempner'],
#  ['Emanuel Ax'],
#  ['David Bury',
#   'Judy Zankel',
#   'Norman Benzaquen',
#   'Georgia Frasch',
#   'Marianne Lockwood'],
#  ['Phyllis Levin'],
#  ['Frances Resheske', 'Marianne Lockwood'],
#  ['Georgia Frasch'],
#  ['Georgia Frasch', 'Ronald Frasch'],
#  ['James Lally', 'Helen Lally'],
#  ['Judi Flom', 'David HyPierce', 'Charles Hamlen', 'Judy Zankel'],
#  ['OSL Katy Clark', 'Norman Haffner'],
#  ['Matthew Feldman', 'Charlottle Lee', 'David Lai'],
#  ['Brian Fisher', 'Joanna Fisher'],
#  ['Steven Leifer', 'Helen', 'Martin Donner'],
#  ['Vicki Kellogg', 'Michael Finn'],
#  ['Susan Gottsegen', 'Peter Gottsegen'],
#  ['Michael Boodro', 'Anita Sarsedi', 'Mitchell Owens', 'Barbara Freidmann'],
#  ['Stephanie Stokes', 'Tom Kligerman'],
#  ['Brain Sawyer', 'Judith Prause'],
#  ['Henry Neville', 'Wendy Moonan', 'Ulrich Leben'],
#  ['Anne Kriken Mann', 'Joanna Bird', 'Susanne Santry'],
#  ['Brandon Correll',
#   'Joshua Amores',
#   'Joel Barkley',
#   'Brian McCarthy',
#   'Todd Klein'],
#  ['Zoe Ryan', 'Barry Bergdoll', 'Barbara Pine'],
#  ['Sarah Ehrlich', 'Liz Hall'],
#  ['Mary Anne Hunting',
#   'Nick Stern',
#   'MaryLouise Napier Zuzunaga',
#   'Courtney Stern'],
#  ['Mabel Wilson', 'Mario Gooden', 'Alan Robinson'],
#  ['Chippy Irvine', 'Betty Scott'],
#  ['Chris Lytle'],
#  ['Michael Gabellini', 'Cintra McGauley'],
#  ['Bob Stern', 'Nick Stern'],
#  ['Fred Bernstein', 'Birch Coffey', 'Anne Edgar', 'Sam Roche', 'Dave Sussman'],
#  ['Jan Aronson',
#   'Matthew Bronfman',
#   'Charles Bronfman',
#   'Stacey Bronfman',
#   'Rita Bronfman'],
#  ['Monty Freeman', 'Abraham Thomas', 'Fred Bernstein'],
#  ['Barrie Pickering', 'Maggie Carey'],
#  ['Richard Sammons', 'Charles Miers'],
#  ['Adam Lerner', 'Thelma Golden', 'David Adjaye'],
#  ['Colette Arredondo', 'John Soane', 'John Flower'],
#  ['Lynn Sherr', 'John McEnroe'],
#  ['Gillian Miniter'],
#  ['Breandan Fallis', 'Hannah Bronfman'],
#  ['Oberlander'],
#  ['Gina Torres'],
#  ['Eaddy Kiernan', 'Indre Rockefeller'],
#  ['Micaela Erlanger'],
#  ['Susan Fales-Hill', 'Bettina Zilkha', 'Caryn Zucker'],
#  ['Misty Copeland', 'Nigel Barker', 'Cristen Barker'],
#  ['Anh Duong'],
#  ['Martine Hamel', 'Kevin McKenzie'],
#  ['Al Roker'],
#  ['Alec Baldwin', 'Rachel Moore'],
#  ['Steven Kobre',
#   'Louise Kornfeld',
#   'Stephen Kornfeld',
#   'Karyn Kornfeld',
#   'Adam Kornfeld',
#   'Joanna Kornfeld',
#   'Paul Friedman'],
#  ['Somers Farkas', 'Chele Chiavacci'],
#  ['Muffie Potter Aston', 'Sherrell Aston'],
#  ['Yasmin Aga Khan', 'Ronnie Spector'],
#  ['Lucia Hwong Gordon', 'Jean Shafiroff'],
#  ['Hilary Gumbel', 'Bryant Gumbel'],
#  ['Karl Wellner'],
#  ['Brooke Shields', 'John McEnroe', 'Patty McEnroe'],
#  ['Charlene Nederlander'],
#  ['Lise Evans', 'Michael Evans'],
#  ['James Nederlander', 'Stewart Lane'],
#  ['Geoffrey Bradfield', 'Jonathan Farkas', 'Robert Zimmerman'],
#  ['Suzanne Murphy', 'Nurit Kahane'],
#  ['Karl Wellner', 'Jones'],
#  ['Liz Lang', 'Mark Locks', 'Mindy Grossman'],
#  ['Harry Johns', 'Brendan Shanahan'],
#  ['Yasmin Aga Khan', 'Bryant Gumbel'],
#  ['Jody Wolf', 'Marla Helen'],
#  ['Lisa Lori', 'Mat Lori'],
#  ['John Meltzer',
#   'Justin Meltzer',
#   'Robin Meltzer',
#   'Martin Meltzer',
#   'Paul Fine',
#   'Lizzie Meltzer',
#   'Amy Meltzer'],
#  ['Alexandra Lebenthal', 'Jay Diamond'],
#  ['Dara Sowell', 'Steve'],
#  ['David Nichol', 'Hal Rubenstein'],
#  ['Harry Johns', 'Lynn Carey', 'Tommy Hilfiger'],
#  ['Allison Mignone'],
#  ['Dana Wallach Jones', 'Amy Griffin'],
#  ['Lisa Schultz', 'Ezriel Kornel', 'Clea Kornel'],
#  ['Daniel R. Garodnick', 'James Lenox House', 'Joseph H. Girven'],
#  ['Roxanne Donovan', 'Jane Smith'],
#  ['Owen Clarkin', 'Terence Campo', 'William Luckey'],
#  ['Kariene Acquafreda'],
#  ['Roxanne Donovan', 'Ralph Daiuto', 'Richard Holowchack', 'Kimberly Allan'],
#  ['Barbara Fleischman', 'Ian Wardropper'],
#  ['Douglas Hyland', 'Elizabeth Gage'],
#  ['Margot Bogert', 'Judith Sanger'],
#  ['Dan Regan', 'Jocelyn Carpenter'],
#  ['Lucy Jane Lang', 'Margi Schwartz'],
#  ['John Dunning'],
#  ['June Dyson', 'James Guedry'],
#  ['Robert L. Froelich', 'Elise Frick', 'John Garraty', 'Emily T. Frick'],
#  ['Daniel Laub', 'Michelle Flesh'],
#  ['Douglas Hyland', 'David Orcutt', 'Sarah McNear', 'Peter Trippi'],
#  ['Colin Bailey', 'Susan Galassi'],
#  ['Jim Jordan', 'Charlotte Verity', 'Christopher LeBrun'],
#  ['Helen Clay Chace', 'Allen'],
#  ['Alexis Light'],
#  ['Barbara Fleischman', 'Joyce Menschel'],
#  ['Caitlin Davis',
#   'Pauline Eveillard',
#   'Clare McKeon',
#   'Colin Bailey',
#   'Lucy Jane Lang'],
#  ['Susan Sloan', 'Arthur Clark', 'Janine Luke'],
#  ['Melinda Sullivan', 'Kathryn Haw'],
#  ['Mark David', 'Claire Distenfeld', 'Rosemary Vrablic', 'Jared Kushner'],
#  ['Colin Bailey', 'Margot Bogert', 'Frick Xavier Salomon', 'Anne Poulet'],
#  ['Frick', 'Tia Chapman', 'Monika McLennan', 'Christopher LeBrun'],
#  ['Christopher LeBrun', 'Monika McLennan'],
#  ['Peter Blanchard'],
#  ['Barbara Fleischman', 'Vartan Gregorian'],
#  ['Margot Bogert', 'Ian Wardropper', 'Barbara Fleischman'],
#  ['Martha Fleischman', 'Barbara Fleischman'],
#  ['Michael Graziano', 'Lisa', 'Richard Baker'],
#  ['Frick', 'Tia Chapman', 'Stanley', 'Elizabeth Scott'],
#  ['Lucy Jane Lang', 'Sarah McNear', 'Frick', 'Colin Bailey'],
#  ['Christopher Apostle', 'Elizabeth Stafford', 'Mark Haukohl'],
#  ['Helen Clay Chace', 'Sarah McNear'],
#  ['Louise Grunwald', 'Douglas Cramer', 'Lynn Nesbit'],
#  ['Lynn Wyatt', 'Christopher Mason'],
#  ['Christopher Mason'],
#  ['Gabriel Gonzalez', 'Jackie Weld Drake'],
#  ['Edgar Batista', 'Audrey Gruss'],
#  ['Elizabeth Jacoby', 'Christopher Trump'],
#  ['Dayssi Olarte Kanavos',
#   'Jeanne Lawrence',
#   'Jamee Gregory',
#   'Helena Martinez'],
#  ['Fred Negem', 'Barbara Tober', 'Donald Tober'],
#  ['Hilda Ochoa-Brillembourg',
#   'Arturo Brillembourg',
#   'Mark Gillespie',
#   'Clara Chopivsky'],
#  ['Irina Serrano', 'Andres Serrano', 'Sabrina Wirth'],
#  ['Jean Shafiroff', 'Dmitri'],
#  ['Jamee Gregory', 'Dmitri'],
#  ['John', 'Kelly Bensimon'],
#  ['Maria Eugenia Haseltine', 'William Haseltine'],
#  ['Juan Larrain', 'Carolina Alvarez-Mathies', 'Rachel Lee Holland'],
#  ['Nina Weir', 'Clara Brillembourg', 'Clara Chopivsky'],
#  ['Francesco Galesi', 'Tina Beriro', 'Peter Bacanovic'],
#  ['Pierre LeVai', 'Marcia Levine'],
#  ['Violaine Bernbach', 'Adrienne Vittadini'],
#  ['Querube Arias Clar', 'JoAnn Mason', 'Hilda Ochoa-Brillembourg'],
#  ['Robertina Calatrava', 'Pierre LeVai'],
#  ['Adrienne Vittadini', 'John Bernbach'],
#  ['Ann Nitze', 'Shayne Doty', 'Julie Geier'],
#  ['Bicky Kellner', 'Steven Aronson', 'Jeannette Sanger', 'George Kellner'],
#  ['Sarah Calderon', 'Jackie Weld Drake', 'Lynn Wyatt', 'Dmitri'],
#  ['Tony Bechara', 'Yolanda Santos'],
#  ['Will Harcourt-Smith', 'Amira Thoron', 'Elise Enders', 'Tom Enders'],
#  ['JoAnn Slattery', 'Laurie Caputo'],
#  ['Gigi Howard', 'Andrea Canning', "Mary D'Alton"],
#  ['Sarah Brown', 'Gigi Howard'],
#  ['Robin Renzi', 'Caroline Foster'],
#  ['Ashley Potter Bruynes', 'Laura McVey', 'Jessica Rochards'],
#  ['Alisa Wood', 'Jennifer Hanley', 'Amy Stuart', 'Kelley Badishkanian'],
#  ['JoAnn Slattery'],
#  ['Nassir Abdulaziz Al-Nasser', 'Susan Gutfreund', 'Muna Rihani Al-Nasser'],
#  ['Sana Saba', 'Mariam Azarm'],
#  ['Mary McFadden'],
#  ['Sam Mallick', 'Valerie Mallick', 'Michael Mallick'],
#  ['Mona Husani', 'Maxima Ghawib'],
#  ['Omar Hilal', 'Nassir Abdulaziz'],
#  ['Phyllis Komansky',
#   'David Komansky',
#   'Cam Patterson',
#   'Erica Silverman',
#   'Sara DiPasquale',
#   'Celia Nichols',
#   'Leiv Schreiber',
#   'Mindy Webster',
#   'Susan Frehse',
#   'Jessica Kisling',
#   'Barbara Landreth',
#   'Kathleen Burns',
#   'Gerald M. Loughlin'],
#  ['Cam Patterson', 'David Komansky', 'Phyllis Komansky', 'Gerald M. Loughlin'],
#  ['DiPasquale',
#   'Erica Silverman',
#   'Mindy Webster',
#   'Jessica Kisling',
#   'Susan Frehse',
#   'Celia Nichols'],
#  ['Samuel Kai Schreiber', 'Alexander Pete Schreiber'],
#  ['Charlie Scheips'],
#  ['Eileen Judell', 'Susan Relyea'],
#  ['Kamie Lightburn', 'Martha Glass', 'John Glass'],
#  ['Barbara McLaughlin', 'Jamie Figg'],
#  ['Stephen Attoe', 'Robert Caravaggi'],
#  ['Jo-Ann Police', 'Karen Klopp'],
#  ['Patricia Burnham Brock', 'William Brock'],
#  ['Laura Whitman', 'Tom Danziger'],
#  ['Claire Bamundo', 'Jack Lynch'],
#  ['Cathie Black',
#   'Cathie Hubbard',
#   'Reem Acra',
#   'Luma Halazon',
#   'Karim Kawar'],
#  ['Tam Tam', 'Noor Altamimi', 'Sarah Altamimi', 'Reem Haj'],
#  [],
#  ['Broadway Julia Murney', 'Composer Steven Jamail'],
#  ['BOU Faisal Al-Juburi', 'Brandon Cardet'],
#  ['CFDA Steven Kolb', 'Reem Acra'],
#  ['Donna Chapman', 'Cathie Black', 'Cathie Hubbard'],
#  ['Judith Lustgarten',
#   'Andre Cox',
#   'Whitney Johson Kerry Whitaker',
#   'Ralph Worthington III',
#   'Bob Munyati'],
#  ['Whitney Johnson', 'Ralph Worthington III', 'Kerry Whitaker'],
#  ['Kerry Whitaker', 'Nancy Moon', 'Whitney Johnson'],
#  ['Jack Guttman', 'Kerry Whitaker', 'Jodi Stuart', 'Jim Roiter'],
#  ['Kerry Whitaker', 'Tom Harritt'],
#  ['Annik Wolf', 'Robyn'],
#  ['Carolyn Tenney', 'Annik Wolf'],
#  ['Shay Behrens', 'Bob Munyati'],
#  ['Jim Roiter', 'Jodi Stuart', 'Jack Guttman'],
#  ['Veronique Gautier', 'Maren Sostmann'],
#  ['Carol Roaman', 'Tsipi Ben-Haim', 'Kerry Whitaker', 'Judith Lustgarten'],
#  ['Ciara Sheridan', 'Azin Valy'],
#  ['Shay Behrens', 'Hannah Smalley', 'Whitney Johnson', 'Robyn'],
#  ['Whitney Johnson', 'Maren Sostmann', 'Macy Johnson'],
#  ['Susan Burke', 'Nicole Limbocker'],
#  ['Boykin Curry', 'Celerie Kemblel'],
#  ['Patricia Kuhl', 'Marc Tessier-Lavigne'],
#  ['Amy Falls'],
#  ['Anna Chapman', 'Addavail Coslett'],
#  ['Eliza Bolen'],
#  ['Ilona Nemeth', 'Alan Quasha'],
#  ['Holly Andersen', 'Judy Roth Berkowitz'],
#  ['Jenny Price', 'Eileen Riano'],
#  ['Katherine Murdoch', 'Beata Lieb'],
#  ['Lindsey Boylan', 'LeRoy Kim'],
#  ['Jean-Pierre Lehman', 'Thomas Pompidou'],
#  ['Courtney Rae'],
#  ['Rebecca Anikstein', 'Lizzie Markus'],
#  ['Rob Davis', 'Marc Tessier-Lavigne'],
#  ['William Meuffling'],
#  ['Alex Shuman', 'Marc Tessier-Lavigne'],
#  ['Sheel Patel', 'Richard Cotton'],
#  ['Ron Pressman', 'Gail', 'Alfred B. Engelberg'],
#  ['H. Carl McCall', 'Stephen Berger'],
#  ['Lawrence Schwartz', 'Howard A. Zucker'],
#  ['Ramanathan Raju', 'M. Sale'],
#  ['Sally J. Rogers',
#   'Christina H. Proscia',
#   'Bill Drover',
#   'Michael J. Noone'],
#  ['Matthew E. Fink', 'Michelle Adams', 'Kenneth E. Raske'],
#  ['Marvin Scott', 'Hazel Cathers'],
#  ['Peter Lebeau', 'Michael Boyd', 'Paul Camellari'],
#  ['Rita Cosby', 'John Catsimatidis'],
#  ['Tamsen Fadal', 'Stephen L. Hoog'],
#  ['Susan Cullman', 'John Kirby'],
#  ['Ana Oliveira',
#   'Ted Bunch',
#   'Anne E. laney',
#   'Retta',
#   'Tony Porter',
#   'Anne Pasternak'],
#  ['Rick Cote', 'Susan Cote'],
#  ['Melanie Contreras', 'Mary Sliwa'],
#  ['David Gordon', 'John Kirby', 'Michele Penzer', 'Tim Kirby'],
#  ['Amelia Ogunlesi', 'Cathy Isaacson'],
#  ['Janet Torres', 'Louis Vega'],
#  ['Eyxa Bazan', 'Mavis Vann'],
#  ['Jane Summers', 'Dara Lamb'],
#  ['Nitzia Logothetis', 'Hyatt Bass', 'Julia Goodman'],
#  ['Cecilia Gaston', 'Zijie Li', 'Shiyu Hu'],
#  ['Felicia Carr', 'Maggie Lannon'],
#  ['Jean Shafiroff', 'Joan Hornig'],
#  [],
#  ['Elizabeth Meyer', 'Mark Meyer'],
#  ['Danielle Brooks', 'Soffiyah Elijah'],
#  ['Andrew Hayward', 'Gillian Steel'],
#  ['Esin Goknar', 'Holly Block', 'Susan Block', 'Fran Barrett', 'Sharon Myrie'],
#  ['Colleen Tierney', 'Lyn Pincus'],
#  ['Susan Kotcher'],
#  ['Martha Sproule', 'Karen Davidson'],
#  ['Danielle Brooks', 'Sarah Jones'],
#  ['Eugene Bowie Roberts', 'Leilani Brenner', 'Jared Hughes'],
#  ['Vivian Spencer', 'Helen'],
#  ['Eugene Roberts', 'Ron Fleming'],
#  ['Bonnie'],
#  ['Anne Dickson Bowen', 'Mary Hilliard'],
#  ['Diana Bunting', 'Carolyn', 'Robert Matheson'],
#  ['Gifts Officer', 'Emmanuel'],
#  ['Jared Hughes'],
#  ['Anita Schnell', 'Steve MacAusland', 'Emmanuel', 'Oscar'],
#  ['Simon Rattle'],
#  ['Simon Rattle'],
#  [],
#  ['Robert Kraft'],
#  ['Joan', 'Sanford I. Weill', 'Carolyn Maloney'],
#  ['Chairwoman Mercedes Bass', 'Barbara Walters'],
#  ['David Siegel', 'Dana Matsushita'],
#  ['Cynthia Sculco', 'Sissy Strauss'],
#  ['Diane Furstenburg', 'Barry Diller'],
#  ['Gala Oscar'],
#  ['Joan', 'Sanford I. Weill', 'Bill Cunningham'],
#  ['Judy Zankel', 'Norman Benzaquen'],
#  ['Simon Rattle', 'Gala Lead Marina Kellen'],
#  ['Carolyn Maloney', 'Gale Brewer'],
#  ['Anne-Sophie Mutter', 'Jessye Norman', 'Richard Wunderlich'],
#  ['Isabel Leonard'],
#  ['Darren Walker', 'Jessye Norman'],
#  ['Jeremy Geffen', 'Marilyn Horne', 'Andre Simmons'],
#  ['Elaine Wolfensohn', 'Marilyn Horne'],
#  ['Graham Parker'],
#  ['Lang Lang', 'Paula Zahn'],
#  ['Mercedes Bass', 'Jim Wolfensohn'],
#  ['Fiction Panelists',
#   'Adam Kolker',
#   'Janet Szabo',
#   'Eva Andersson-Dubin',
#   'Elisa Port',
#   'Jeffery Mechanick',
#   'Amy Tiersten'],
#  ['Lesley Schulhof', 'Natasha Cornstein'],
#  ['Iris Dankner', 'Landis'],
#  ['Tricia Foley', 'Paula Cleary', 'Elisa Port'],
#  ['Bonnie Pferfer'],
#  ['Lise Evans', 'Andrea Glimcher'],
#  ['Kris Fuchs', 'Sonia Jones', 'Eva Andersson-Dubin'],
#  ['Barbara Siegler', 'Emily Blavatnik'],
#  ['Wayne Froud', 'Alexandra Yperifanos'],
#  ['Marc Caputo', 'Stacey Pashcow'],
#  ['Amy Tiersten', 'Sarah Amaden'],
#  ['Krista Kreiger',
#   'Nicole Mollo',
#   'Richard Ruggiero',
#   'Bryan Christy',
#   'Sara Thompkins',
#   'Sara Thompkins'],
#  ['Jess Gruner', 'Peter Fearnhead', 'Ron Ulrich', 'Andrew Parker'],
#  ['David Koch', 'Nicole Mollo'],
#  ['David Koch', 'Jimmy Coleman'],
#  ['Darleen Kasten'],
#  ['Bryan Christy', 'Darleen Anderson'],
#  ['Steven Stone', 'David Hodin', 'JJ Kelley'],
#  ['Barbara Doran', 'Marvin', 'Donna Schwartz'],
#  ['Andrew Parker', 'Anna McWane', 'Jess Gruner'],
#  ['Bonnie Hlinomaz', 'Natalie Anderson', 'Pam Ulm'],
#  ['Richard Ruggiero', 'Heidi Lange', 'Christian Lange'],
#  ['Olga Neulist', 'Herb Wetson', 'Maura Rose'],
#  ['Nicole Mollo', 'Bryan Christy'],
#  ['Marc Wolinsky', 'Barry Skovgaard'],
#  ['Ron Ulrich'],
#  ['Sandra Turner', 'Sherry Henry'],
#  ['Samantha Tritsch',
#   'William Lauder',
#   'Myra Biblowit',
#   'Giuliana Rancic',
#   'Lori Tritsch'],
#  ['Anna Mattera', 'Heidi Taylor', 'Jessie Elsas', 'Cindy Citrone', 'Kim Meir'],
#  ['Willie Geist', 'Giuliana Rancic'],
#  ['Chris Benz'],
#  ['Courtney Keegan', 'Tom Keegan', 'Patti Keegan'],
#  ['Marisa Renee Lee', 'Meghan Rooney', 'Dani Haskin', 'Jaquelyn Scharnick'],
#  ['Emilia Bechrakis'],
#  ['Jacquelyn Sharnick', 'Giuliana Rancic', 'Marisa Renee Lee'],
#  ['Jon Passavant', 'Bhavna Lal', 'Benj Lee', 'Hannah Bronfman'],
#  ['Jill Martin', 'Gail Grimmett'],
#  ['Samantha Tritsch', 'Danielle Bernstein'],
#  ['Lenny Platt'],
#  ['Ryan Fuld', 'Alli Stein', 'Hannah Bronfman'],
#  ['Nick Wolf'],
#  ['Carla Franklin', 'Bryan Richards'],
#  ['John Maisey', 'Zachary', 'Lori Pomerantz'],
#  ['Lou-Ellen Barkan', 'Liz Johnson'],
#  ['Kevin Long', 'Jason Leier', 'Chris Farwell', 'Jared Karlebach'],
#  ['Charles Chasin', 'Jennifer Ashley', 'Mark Bavaro'],
#  ['Diana Gaines', 'Sheri Danehy'],
#  ['Giselle Stolper', 'Kevin Danehy'],
#  ['Tamsen Fadal', 'Scott Stanford'],
#  ['Teresa Priolo', 'Jared Kirschner'],
#  ['Ciara Dockery', 'Dwight Hollier'],
#  ['Ric Clark', 'Giselle Stolper'],
#  ['Kimberly Rockefeller', 'Jay McInerney'],
#  ['Lucia Hwong Gordon', 'Angela Bernhard Thomas'],
#  ['Sharon Bush', 'Tom Knapp', 'Anne Hearst'],
#  ['Sasha Lloyd', 'James Frances Ginty'],
#  ['Alex Donner', 'Annette  Lorenzo'],
#  ['Jean Shafiroff', 'Erik Bottcher'],
#  ['Campion Platt', 'Audrey Gruss'],
#  ['R. Couri Hay', 'Sonja Morgan'],
#  ['Larry Wohl', 'Leesa Rowland'],
#  ['Greg Cameron', 'Ellie Forman', 'Ashley Wheater', 'Kathleen Henson'],
#  ['Katie Freiburger', 'Raheela Anwar'],
#  ['Carol Stone', 'Laura Kofoid'],
#  ['Victoria Jaiani', 'Ashley Wheater'],
#  ['Casalino',
#   'Connie Gerber',
#   'Gloria Schaffer',
#   'Liz Sharp',
#   'Maureen Gorman'],
#  ['Cheryl Tana Oblander', 'Elizabeth Yntema'],
#  ['Brooke Hubbuch', 'Maria Pinto'],
#  ['Sonya Jackson', 'Rochelle Trotter'],
#  ['Megan Van Pelt', 'Carolyn Blessing'],
#  ['Tarrah Cooper', 'Nicole Johnson-Scales', 'Erica Edwards'],
#  ["Abby McCormick O'Neil", 'Martha Melman', 'Suzy Friedman'],
#  ['John Picone', 'John Glotzbach', 'Brian Morgan'],
#  ['Anne Hearst McInerney', 'Jay McInerney'],
#  ['Annie Berkery', 'Amanda Hearst', 'Jamie Katz'],
#  ['Anne Hearst McInerney', 'Stefan Hearst'],
#  ['Eric Sheehan', 'Kick Kennedy', 'Ben Berube'],
#  ['Chonita Cleary',
#   'Michelle Cleary',
#   'Alison Mazzola',
#   'Sylvia Mazzola',
#   "Michelle d'Arcambal"],
#  ['Jonathan Lonsdale',
#   'Tatiana Merel',
#   "John O'Connor",
#   'Remar Sutton',
#   'Tayler Cox',
#   'Joe Lonsdale'],
#  ['Robert Bloomingdale',
#   'Julie Tobias',
#   'Lester Tobias',
#   'Suzanne Trepp',
#   'Peter Trepp'],
#  ['Wendy Stark', 'George Farias'],
#  ['Zoe Bullock', 'James Coleman', 'Cynthia Ott'],
#  ['Meredith Randol', 'Randy Harris', 'James Casale', 'Ciana Barrom'],
#  ['Paula Peck', 'Tony Peck'],
#  ['Randy Harris', 'Amanda Hearst'],
#  ['Sylvia Mazzola', 'Jamie Figg'],
#  ['Jane Moggio', 'Alatia Bradley', 'Ashley Christopher'],
#  ['Aylin Brenna', 'Melanie Chisholm'],
#  ['Allison Strong', 'Anna Lynn Oppenheimer', 'Lee Baratier'],
#  ['Jennifer Lavin', 'Andali Pant'],
#  ['Parisa Jaffer'],
#  ['Joni Grossman'],
#  ['Camilla Islam'],
#  ['Anna Lynn Oppenheimer', 'Allison Strong', 'Lawrence Rosen', 'Lisa Lambert'],
#  [],
#  ['Kamie Lightburn', 'Nicole Eades', 'Paige Bett'],
#  ['Kristen Genovese'],
#  ['Kamie Lightburn', 'Bernadine Dilfond', 'Rima Parachini'],
#  ["Molly O'Mara Sheehan", 'Ellen Turchyn'],
#  ['Margot Takian', "Molly O'Mara Sheehan"],
#  ['Sharon Giese', 'Carmen Gutierrez'],
#  ['Cece Coffin', 'Emily Garbaccio'],
#  ['Mary Pelt', 'Jane Moggio', 'Peyton Muldoon'],
#  ['Nancy Huh', 'Jennifer Lavin'],
#  ['Naomi Daniels', 'Dallas Rexer'],
#  ['Sharon Monahan', 'Lisa Martin'],
#  ['Valerie Bruce',
#   'Tara Liddle',
#   'Nina Kohler',
#   'Krysten Plynn',
#   'Lee Baratier'],
#  ['Brian McCarthy', 'Sandra Nunnerley', 'Ralph Pucci'],
#  ['Dick Solomon', 'Robert Newman', 'Michele Senecal'],
#  ['Brian McCarthy', 'Sandra Nunnerley', 'Matthew Patrick Smyth'],
#  ['Margaret Russell', 'Ralph Pucci'],
#  ['Caroline Sollis', 'Janice Langrall'],
#  ...]

# %% [markdown]
# The end result is just a list of lists. Each component list contains only the names that appear in every photocaption of photos from every event before 12/1/14.

# %%
names = only_names_captions

print(len(names))
# Out:
# 83915
